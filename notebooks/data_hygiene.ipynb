# %%
import pandas as pd
import numpy as np
from preprocess import data_hygiene
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-70-4b2d8f30de22> in <module>()
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 from preprocess import data_hygiene
#
# ImportError: No module named preprocess

# %%
def read_mongo(database_name, collection_name, query={}, no_id=False):
    """ Read from Mongo and Store into DataFrame """

    # Get MongoDB
    mc = MongoClient()
    db = mc[database_name]
    petitions_col = db[collection_name]

    # Make a query to the specific DB and Collection
    cursor = db[collection_name].find(query)

    # Expand the cursor and construct the DataFrame
    df = pd.DataFrame(list(cursor))

    # Delete the _id
    if no_id:
        del df['_id']

    return df

# %%
data.head().T
# Out:
#                                                                                  0  \
# _id                                                       5780937fd9ccb32891d1cbb7
# ask                               Freeze all of BP's assets, before it is too late
# calculated_goal                                                               5000
# category                                                               Environment
# created_at                                                    2010-05-31T09:14:21Z
# creator_city                                                          West Chester
# creator_country                                                                 US
# creator_description               I am a spinal injury patient. I need to have ...
# creator_display_name                                       Christopher David Moore
# creator_fb_permissions                                                           0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 67 columns):
# _id                                1000 non-null object
# ask                                1000 non-null object
# calculated_goal                    1000 non-null int64
# category                           794 non-null object
# created_at                         1000 non-null object
# creator_city                       888 non-null object
# creator_country                    1000 non-null object
# creator_description                456 non-null object
# creator_display_name               881 non-null object
# creator_fb_permissions             881 non-null float64
# creator_first_name                 881 non-null object
# creator_has_address                119 non-null object
# creator_has_contact_email          119 non-null object
# creator_has_fb_page                119 non-null object
# creator_has_photo                  1000 non-null bool
# ...

# %%
data[""data["goal"] < 100""]

# %%
data["description"].apply(lambda x: "" id np.i)

# %%
data["creator_description"].apply(len)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-62-30b785a7fb09> in <module>()
# ----> 1 data["creator_description"].apply(len)
#
# /Users/natalie/anaconda/lib/python2.7/site-packages/pandas/core/series.pyc in apply(self, func, convert_dtype, args, **kwds)
#    2235             values = lib.map_infer(values, boxer)
#    2236
# -> 2237         mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2238         if len(mapped) and isinstance(mapped[0], Series):
#    2239             from pandas.core.frame import DataFrame
#
# pandas/src/inference.pyx in pandas.lib.map_infer (pandas/lib.c:63043)()
#
# TypeError: object of type 'float' has no len()

# %%
len(data.iloc[2]["creator_description"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-ce25a99f8e5a> in <module>()
# ----> 1 len(data.iloc[5]["creator_description"])
#
# TypeError: object of type 'float' has no len()

# %%
data.iloc[5]["creator_description"]
# Out:
# nan
