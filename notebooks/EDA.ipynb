# %%
from data_hygiene import read_mongo
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-219-aacbc8379ed9> in <module>()
# ----> 1 from data_hygiene import read_mongo, clean_data
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
#       4 import pandas as pd
#       5 get_ipython().magic(u'matplotlib inline')
#
# ImportError: cannot import name clean_data

# %%
# db.us_closed_petitions.find({petition_id: {$lt: 236494}}).count()

# %%
data = read_mongo("changeorg", "us_closed_petitions", {"petition_id": {"$lt": 236494}})

# %%
data.head().T
# Out:
#                                                                                  0  \
# _id                                                       5780937fd9ccb32891d1cbb7
# ask                               Freeze all of BP's assets, before it is too late
# calculated_goal                                                               5000
# category                                                               Environment
# created_at                                                    2010-05-31T09:14:21Z
# creator_city                                                          West Chester
# creator_country                                                                 US
# creator_description               I am a spinal injury patient. I need to have ...
# creator_display_name                                       Christopher David Moore
# creator_fb_permissions                                                           0
# creator_first_name                                               Christopher David
# creator_has_address                                                            NaN
# creator_has_contact_email                                                      NaN
# creator_has_fb_page                                                            NaN
# creator_has_slug                                                              True
# creator_has_twitter                                                            NaN
# creator_has_verified_at                                                        NaN
# creator_has_verified_by                                                        NaN
# creator_has_verified_req                                                       NaN
# creator_has_video                                                              NaN
# creator_has_website                                                           True
# creator_last_name                                                            Moore
# creator_locale                                                               en-US
# creator_mission                                                                NaN
# creator_name                                               Christopher David Moore
# creator_org_name                                                               NaN
# creator_photo                          photos/6/qj/ny/hfQJNyHYFKVqFNX-fullsize.jpg
# creator_postal_code                                                            NaN
# creator_state                                                                   PA
# creator_tax_country_code                                                       NaN
# ...                                                                            ...
# displayed_signature_count                                                      279
# end_at                                                        2010-08-29T23:59:59Z
# goal                                                                          5000
# has_video                                                                    False
# image_url                        https://d22r54gnmuhwmk.cloudfront.net/app-asse...
# is_pledge                                                                    False
# is_verified_victory                                                          False
# is_victory                                                                   False
# languages                                                                     [en]
# last_past_verified_victory_date                                               None
# last_past_victory_date                                                        None
# letter_body                      You must freeze all of BP's assets before they...
# num_past_petitions                                                               0
# num_past_verified_victories                                                      0
# num_past_victories                                                               0
# organization_name                                                             None
# organization_url                                                              None
# original_locale                                                              en-US
# overview                         <p>In the construction industry, builders that...
# petition_id                                                                  30001
# photo                                                                         None
# progress                                                                      5.58
# signature_count                                                                279
# status                                                                      closed
# tags                                                                 [Environment]
# targets                          [{u'type': u'us_government', u'name': u'Presid...
# targets_detailed                 [{u'publicly_visible': False, u'slug': u'u-s-h...
# title                             Freeze all of BP's assets, before it is too late
# url                              https://api.change.org/p/freeze-all-of-bp-s-as...
# victory_date                                                                  None
#
#                                                                                  1  \
# _id                                                       5780937fd9ccb32891d1cbb9
# ask                                       Dont mix Catholic Mass, with Gay Bashing
# calculated_goal                                                                500
# category                                                                Gay Rights
# created_at                                                    2010-05-31T10:20:59Z
# creator_city                                                              Hinckley
# creator_country                                                                 US
# creator_description              I am so liberal, I believe  its a given - ever...
# creator_display_name                                             jan Lightfootlane
# creator_fb_permissions                                                           0
# creator_first_name                                                             jan
# creator_has_address                                                            NaN
# creator_has_contact_email                                                      NaN
# creator_has_fb_page                                                            NaN
# creator_has_slug                                                              True
# creator_has_twitter                                                            NaN
# creator_has_verified_at                                                        NaN
# creator_has_verified_by                                                        NaN
# creator_has_verified_req                                                       NaN
# creator_has_video                                                              NaN
# creator_has_website                                                           True
# creator_last_name                                                    Lightfootlane
# creator_locale                                                               en-US
# creator_mission                                                                NaN
# creator_name                                                     jan Lightfootlane
# creator_org_name                                                               NaN
# creator_photo                          photos/7/iv/wm/ZaIVwMDzCcHPHuW-fullsize.jpg
# creator_postal_code                                                            NaN
# creator_state                                                                   ME
# creator_tax_country_code                                                       NaN
# ...                                                                            ...
# displayed_signature_count                                                       35
# end_at                                                        2010-08-29T23:59:59Z
# goal                                                                           500
# has_video                                                                    False
# image_url                        https://d22r54gnmuhwmk.cloudfront.net/app-asse...
# is_pledge                                                                    False
# is_verified_victory                                                          False
# is_victory                                                                   False
# languages                                                                     [en]
# last_past_verified_victory_date                                               None
# last_past_victory_date                                                        None
# letter_body                      This is an important Constitutional issue. So ...
# num_past_petitions                                                               0
# num_past_verified_victories                                                      0
# num_past_victories                                                               0
# organization_name                                                             None
# organization_url                                                              None
# original_locale                                                              en-US
# overview                         <p>If state cannot mix with the church busines...
# petition_id                                                                  30003
# photo                                                                         None
# progress                                                                         7
# signature_count                                                                 35
# status                                                                      closed
# tags                                                                 [LGBT rights]
# targets                          [{u'type': u'us_government', u'name': u'Maine ...
# targets_detailed                 [{u'publicly_visible': False, u'slug': u'maine...
# title                                     Dont mix Catholic Mass, with Gay Bashing
# url                              https://api.change.org/p/dont-mix-catholic-mas...
# victory_date                                                                  None
#
#                                                                                  2  \
# _id                                                       5780937fd9ccb32891d1cbba
# ask                              Week 65–Ask FIVE more congress representative ...
# calculated_goal                                                                500
# category                                                          Immigrant Rights
# created_at                                                    2010-05-31T10:37:39Z
# creator_city                                                         San Francisco
# creator_country                                                                 US
# creator_description
# creator_display_name                                                      Amos Lim
# creator_fb_permissions                                                           0
# creator_first_name                                                            Amos
# creator_has_address                                                            NaN
# creator_has_contact_email                                                      NaN
# creator_has_fb_page                                                            NaN
# creator_has_slug                                                              True
# creator_has_twitter                                                            NaN
# creator_has_verified_at                                                        NaN
# creator_has_verified_by                                                        NaN
# creator_has_verified_req                                                       NaN
# creator_has_video                                                              NaN
# creator_has_website                                                           True
# creator_last_name                                                              Lim
# creator_locale                                                               en-US
# creator_mission                                                                NaN
# creator_name                                                              Amos Lim
# creator_org_name                                                               NaN
# creator_photo                          photos/6/ml/ox/QUmloXpxmjzAAsK-fullsize.jpg
# creator_postal_code                                                            NaN
# creator_state                                                                   CA
# creator_tax_country_code                                                       NaN
# ...                                                                            ...
# displayed_signature_count                                                      202
# end_at                                                        2010-11-10T23:59:59Z
# goal                                                                           500
# has_video                                                                    False
# image_url                        https://d22r54gnmuhwmk.cloudfront.net/photos/9...
# is_pledge                                                                    False
# is_verified_victory                                                          False
# is_victory                                                                   False
# languages                                                                     [en]
# last_past_verified_victory_date                                               None
# last_past_victory_date                                                        None
# letter_body                      I am writing to ask you for your support by be...
# num_past_petitions                                                               0
# num_past_verified_victories                                                      0
# num_past_victories                                                               0
# organization_name                                                             None
# organization_url                                                              None
# original_locale                                                              en-US
# overview                         <p>This week's letter writing campaign is dire...
# petition_id                                                                  30004
# photo                                  photos/9/ur/dk/TUuRDKtkcPAiGIx-fullsize.jpg
# progress                                                                      40.4
# signature_count                                                                202
# status                                                                      closed
# tags                                                                            []
# targets                          [{u'type': u'us_government', u'name': u'Rep. P...
# targets_detailed                 [{u'publicly_visible': False, u'slug': u'pete-...
# title                            Week 65–Ask FIVE more congress representative ...
# url                              https://api.change.org/p/week-65-ask-five-more...
# victory_date                                                                  None
#
#                                                                                  3  \
# _id                                                       57809380d9ccb32891d1cbbc
# ask                                                      Nada's Plight for Justice
# calculated_goal                                                                500
# category                                                       End Sex Trafficking
# created_at                                                    2010-05-31T13:03:53Z
# creator_city                                                               Niangua
# creator_country                                                                 US
# creator_description
# creator_display_name                                                       T Baker
# creator_fb_permissions                                                           0
# creator_first_name                                                               T
# creator_has_address                                                            NaN
# creator_has_contact_email                                                      NaN
# creator_has_fb_page                                                            NaN
# creator_has_slug                                                              True
# creator_has_twitter                                                            NaN
# creator_has_verified_at                                                        NaN
# creator_has_verified_by                                                        NaN
# creator_has_verified_req                                                       NaN
# creator_has_video                                                              NaN
# creator_has_website                                                           True
# creator_last_name                                                            Baker
# creator_locale                                                               pt-BR
# creator_mission                                                                NaN
# creator_name                                                               T Baker
# creator_org_name                                                               NaN
# creator_photo                          photos/3/dr/nu/ErDrNuivXzJmakZ-fullsize.jpg
# creator_postal_code                                                            NaN
# creator_state                                                                   MO
# creator_tax_country_code                                                       NaN
# ...                                                                            ...
# displayed_signature_count                                                      244
# end_at                                                        2012-03-01T23:59:59Z
# goal                                                                           500
# has_video                                                                    False
# image_url                        https://d22r54gnmuhwmk.cloudfront.net/photos/1...
# is_pledge                                                                    False
# is_verified_victory                                                          False
# is_victory                                                                   False
# languages                                                                     [en]
# last_past_verified_victory_date                                               None
# last_past_victory_date                                                        None
# letter_body                      Mrs. Nada Nadim Prouty is a former FBI and CIA...
# num_past_petitions                                                               0
# num_past_verified_victories                                                      0
# num_past_victories                                                               0
# organization_name                                                             None
# organization_url                                                              None
# original_locale                                                              en-US
# overview                         <p>Nada was born in Lebanon. Her father was a ...
# petition_id                                                                  30006
# photo                                  photos/1/pf/us/VsPFUSVJMLGDBVD-fullsize.jpg
# progress                                                                      48.8
# signature_count                                                                244
# status                                                                      closed
# tags                                                                [Human Rights]
# targets                          [{u'type': u'us_government', u'name': u'Presid...
# targets_detailed                 [{u'publicly_visible': True, u'slug': u'presid...
# title                                                    Nada's Plight for Justice
# url                              https://api.change.org/p/nada-s-plight-for-jus...
# victory_date                                                                  None
#
#                                                                                  4
# _id                                                       57809380d9ccb32891d1cbbd
# ask                              Dear Russia, Please Don't Cut Support for Traf...
# calculated_goal                                                                500
# category                                                         Human Trafficking
# created_at                                                    2010-05-31T13:04:22Z
# creator_city                                                               Rowlett
# creator_country                                                                 US
# creator_description              I am an abolitionist fighting against modern d...
# creator_display_name                                    John Burger AbolitionistJB
# creator_fb_permissions                                                           0
# creator_first_name                                                     John Burger
# creator_has_address                                                            NaN
# creator_has_contact_email                                                      NaN
# creator_has_fb_page                                                            NaN
# creator_has_slug                                                              True
# creator_has_twitter                                                            NaN
# creator_has_verified_at                                                        NaN
# creator_has_verified_by                                                        NaN
# creator_has_verified_req                                                       NaN
# creator_has_video                                                              NaN
# creator_has_website                                                           True
# creator_last_name                                                   AbolitionistJB
# creator_locale                                                               en-US
# creator_mission                                                                NaN
# creator_name                                            John Burger AbolitionistJB
# creator_org_name                                                               NaN
# creator_photo                          photos/1/jh/dv/nQjhDvmPaRYuchX-fullsize.jpg
# creator_postal_code                                                            NaN
# creator_state                                                                   TX
# creator_tax_country_code                                                       NaN
# ...                                                                            ...
# displayed_signature_count                                                      309
# end_at                                                        2010-08-29T23:59:59Z
# goal                                                                           500
# has_video                                                                    False
# image_url                        https://d22r54gnmuhwmk.cloudfront.net/photos/9...
# is_pledge                                                                    False
# is_verified_victory                                                          False
# is_victory                                                                   False
# languages                                                                     [en]
# last_past_verified_victory_date                                               None
# last_past_victory_date                                                        None
# letter_body                      Human trafficking is a major issue throughout ...
# num_past_petitions                                                               0
# num_past_verified_victories                                                      0
# num_past_victories                                                               0
# organization_name                                                             None
# organization_url                                                              None
# original_locale                                                              en-US
# overview                         <p>Russia is cutting their Human Trafficking V...
# petition_id                                                                  30007
# photo                                  photos/9/wc/wu/GlWcWuuMoqUYFFZ-fullsize.jpg
# progress                                                                      61.8
# signature_count                                                                309
# status                                                                      closed
# tags                                             [human trafficking, Human Rights]
# targets                          [{u'type': u'custom', u'name': u'Office of the...
# targets_detailed                 [{u'publicly_visible': False, u'slug': u'offic...
# title                            Dear Russia, Please Don't Cut Support for Traf...
# url                              https://api.change.org/p/dear-russia-please-do...
# victory_date                                                                  None
#
# [67 rows x 5 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9423 entries, 0 to 9422
# Data columns (total 67 columns):
# _id                                9423 non-null object
# ask                                9422 non-null object
# calculated_goal                    9422 non-null float64
# category                           7671 non-null object
# created_at                         9423 non-null object
# creator_city                       8625 non-null object
# creator_country                    9422 non-null object
# creator_description                4008 non-null object
# creator_display_name               8394 non-null object
# creator_fb_permissions             8394 non-null float64
# creator_first_name                 8394 non-null object
# creator_has_address                1028 non-null object
# creator_has_contact_email          1028 non-null object
# creator_has_fb_page                1028 non-null object
# creator_has_slug                   9422 non-null object
# creator_has_twitter                1028 non-null object
# creator_has_verified_at            1028 non-null object
# creator_has_verified_by            1028 non-null object
# creator_has_verified_req           1028 non-null object
# creator_has_video                  1028 non-null object
# creator_has_website                9422 non-null object
# creator_last_name                  8394 non-null object
# creator_locale                     8394 non-null object
# creator_mission                    1024 non-null object
# creator_name                       8395 non-null object
# creator_org_name                   1028 non-null object
# creator_photo                      6578 non-null object
# creator_postal_code                986 non-null object
# creator_state                      8609 non-null object
# creator_tax_country_code           0 non-null float64
# creator_tax_state_code             0 non-null float64
# creator_type                       9422 non-null object
# creator_url                        8395 non-null object
# creator_zipcode                    986 non-null object
# description                        9422 non-null object
# discoverable                       9422 non-null object
# display_title                      9422 non-null object
# displayed_signature_count          9422 non-null float64
# end_at                             9423 non-null object
# goal                               9423 non-null int64
# has_video                          9422 non-null object
# image_url                          9423 non-null object
# is_pledge                          9422 non-null object
# is_verified_victory                9422 non-null object
# is_victory                         9422 non-null object
# languages                          9422 non-null object
# last_past_verified_victory_date    740 non-null object
# last_past_victory_date             747 non-null object
# letter_body                        9423 non-null object
# num_past_petitions                 9422 non-null float64
# num_past_verified_victories        9422 non-null float64
# num_past_victories                 9422 non-null float64
# organization_name                  1028 non-null object
# organization_url                   1028 non-null object
# original_locale                    9422 non-null object
# overview                           9423 non-null object
# petition_id                        9423 non-null int64
# photo                              6127 non-null object
# progress                           9422 non-null float64
# signature_count                    9423 non-null int64
# status                             9423 non-null object
# tags                               9422 non-null object
# targets                            9423 non-null object
# targets_detailed                   9422 non-null object
# title                              9423 non-null object
# url                                9423 non-null object
# victory_date                       124 non-null object
# dtypes: float64(9), int64(3), object(55)
# memory usage: 4.8+ MB

# %% [markdown]
# ### number of victories and verified victories

# %%
data[data.status == "victory"]["status"].count()
# Out:
# 131

# %%
data[data.is_verified_victory == True]["status"].count()
# Out:
# 119

# %%
data[data.status == "closed"]["status"].count()
# Out:
# 9292

# %%
data.shape
# Out:
# (9423, 67)

# %% [markdown]
# ### Getting length of description

# %%
data["description"] = data["description"].replace(np.nan,'', regex=True)

# %%
data['description_len']=data["description"].apply(len)

# %% [markdown]
# ### Getting length of creator description

# %%
data["creator_description"] = data["creator_description"].replace(np.nan,'', regex=True)

# %%
data["creator_description_len"] = data["creator_description"].apply(len)

# %% [markdown]
# ### Getting length of title

# %%
data["title"] = data["title"].replace(np.nan,'', regex=True)

# %%
data["title_len"] = data["title"].apply(len)

# %% [markdown]
# ### Has image?

# %%
data["has_image"] = data["image_url"] != np.nan

# %% [markdown]
# ### Number of tags

# %%
def get_length_tags(x):
    try:
        return  len(x)
    except:
         return  0

# %%
data["num_tags"] = data["tags"].apply(get_length_tags)

# %% [markdown]
# ### Creator has twitter

# %%
data["creator_has_twitter"] =  data["creator_has_twitter"].replace(np.nan,False)

# %% [markdown]
# ### Number of targets

# %%
data["num_targets"] = data["targets"].apply(len)

# %% [markdown]
# ### Length letter

# %%
data["letter_body_len"] = data["letter_body"].apply(len)

# %% [markdown]
# ### Convert to datetime

# %%
data["created_at"] = pd.to_datetime(data["created_at"])

# %%
data["end_at"] = pd.to_datetime(data["end_at"])

# %%
data['time_range'] = (data["end_at"] - data["created_at"]).apply(lambda x: x.days)

# %% [markdown]
# ## Some histograms

# %%
filtered_data = data[["petition_id", "status", "category", "creator_state", \
      "creator_country", "title_len", "description_len", "creator_description_len", \
     "goal", "calculated_goal", "is_verified_victory", "num_past_victories", \
     "created_at", "end_at", "has_image", "num_tags", "has_video", \
     "num_targets", "creator_type", "letter_body_len", "creator_has_website", \
    "creator_has_twitter", "original_locale", "time_range"]]

# %%
filtered_data["time_range"].hist(bins= 40)

# %%
filtered_data["description_len"].hist(bins= 60)

# %%
filtered_data["creator_description_len"].hist(bins= 60)

# %%
filtered_data["title_len"].hist(bins= 60)

# %%
filtered_data["letter_body_len"].hist(bins= 60)

# %%
filtered_data["goal"].hist(bins= 60)

# %%
filtered_data["calculated_goal"].hist(bins= 60)

# %%
filtered_data["creator_has_website"].hist()

# %%
filtered_data["creator_has_twitter"].hist()

# %%
filtered_data["num_past_victories"].hist(bins= 10)

# %% [markdown]
# ## scatter matrix

# %%
pd.scatter_matrix(filtered_data, alpha=0.2, figsize=(20, 20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x12b962e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1317840d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x131c983d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1318c7fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x131f77690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x131fe97d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x131f878d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13217b110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1321e3cd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x132265250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x132129a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13232f910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1323a7790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13240b690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x132484510>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1324e0510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x132557490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1324ec8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x132634190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1326a0fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13292ea50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1329ac9d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x132a0c910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x132a8a890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x132ac19d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x132b79910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x132bfc790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x132c60790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x132ce3710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x132c79e90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x132dd5590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x132f58410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x132fb7cd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13303cc50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1330a1b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x133121b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x133130ed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x133413b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x133496a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1334fc950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13367e7d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1336e44d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12ae78190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x129717a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13372e950>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1337ab8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x133751050>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x134099950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13411d7d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13417edd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x134204c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x134267c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1342eac10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1342f7b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1343da9d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13445e850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1344c1b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x134646990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1346ac690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x134736790>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1347ba610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x134a29090>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x134a9eed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x134af8f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x134c85e90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x134cbfed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x134d77c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x134dfcad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x134e5dd90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x134ee1c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x134f49910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x134fd1a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x135056890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1350c5310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x135149190>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1351ad1d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13522e150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x135267190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x135412ed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x135496d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x135609050>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13567ee90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1356e5b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13576ec90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1357f2b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x136961590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1369e5410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x136b4b450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x136bcd3d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x136c05410>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x136cbe190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x136d34fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x136da62d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x136f27150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x136f82e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13700bf10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x137090d90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1370ff810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x137282690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1372e56d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x137369650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1373a1690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x137459410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1374de290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x137541550>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1375c33d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13762b0d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1376b51d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13793a050>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13799ba90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x137b1f910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x137b83950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x137c068d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x137c3e910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x137cf6690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x137d7a510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x137ddd7d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x137e60650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x137ec9350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x137f51450>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x137fd62d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x138136d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1381bab90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13821fbd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1382a0b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1382b0f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x138592910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x138615790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13867ba50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1386fe8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1387635d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1387ee6d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x138873550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1388d3f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x138a57e10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x138abce50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x138b3edd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x138b77e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x138d2fb90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x138db3a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x138e15cd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x138e9ab50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x138f01850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x138f8a950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13900e7d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x134e144d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1390b6210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x139204fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13929d110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x139415f50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x139481fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x139506e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x139569d90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1395ecc10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x139755910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1397dfa10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13a062890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13a0d0310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13a154190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13a1b71d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13a23a150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13a272190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13a41fed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13a4a2d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13a516050>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x13a588e90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13a5f2b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13a779c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13a7fcb10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13a86b590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13a8f1410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13aa55450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13aad93d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13ab0f410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13abc9190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13ac3efd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13acb02d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13af33150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13af8ee10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13b818f10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x13b89bd90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13b90a810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13b98d690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13b9f16d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13ba74650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13baac690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13bc65410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13bce8290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13bd4c550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13bdcd3d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13be360d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13bec11d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13c045050>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13c0a7a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13c22a910>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x13c28e950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13c3108d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13c349910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13c462690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13c4e5510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13c5497d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13c5cc650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13c754350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13c7dd450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13d0612d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13d0c1d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13d145b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13d1ebbd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13d36cb50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13d37af90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x13d45f910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13d4e1790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13d546a50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13d5c98d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13d7305d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13d7bb6d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13d93e550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13d9a1f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13db22e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13db88e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13dc08dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13dc42e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13dcfbb90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13dd7ea10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13dde2cd0>]], dtype=object)

# %%
filtered_data[filtered_data["status"] == "victory"].T
# Out:
#                                         521                  585   \
# petition_id                            31171                31331
# status                               victory              victory
# category                             Animals           Gay Rights
# creator_state                           None                   NY
# creator_country                           US                   US
# title_len                                 46                   34
# description_len                         2192                 1143
# creator_description_len                    0                   16
# goal                                    5000                 2000
# calculated_goal                         5000                 2000
# is_verified_victory                     True                 True
# num_past_victories                         3                    1
# created_at               2010-07-04 22:33:29  2010-07-09 19:08:38
# end_at                   2010-07-15 23:59:59  2011-06-26 23:59:59
# has_image                               True                 True
# num_tags                                   5                    2
# has_video                              False                False
# num_targets                                3                    1
# creator_type                            user                 user
# letter_body_len                         1727                  955
# creator_has_website                     True                 True
# creator_has_twitter                    False                False
# original_locale                        en-US                en-US
# time_range                                11                  352
#
#                                         668                  720   \
# petition_id                            31469                31546
# status                               victory              victory
# category                    Criminal Justice    Human Trafficking
# creator_state                             IL                   HI
# creator_country                           US                   US
# title_len                                 75                   66
# description_len                         1357                  779
# creator_description_len                  271                    0
# goal                                     200                 3000
# calculated_goal                          200                 3000
# is_verified_victory                     True                 True
# num_past_victories                        10                    2
# created_at               2010-07-14 13:23:11  2010-07-17 15:19:57
# end_at                   2010-07-16 23:59:59  2011-04-28 23:59:59
# has_image                               True                 True
# num_tags                                   2                    2
# has_video                              False                False
# num_targets                                1                    5
# creator_type                            user                  org
# letter_body_len                         1659                 1574
# creator_has_website                     True                 True
# creator_has_twitter                    False                False
# original_locale                        en-US                en-US
# time_range                                 2                  285
#
#                                         858                  870   \
# petition_id                            31838                31871
# status                               victory              victory
# category                             Animals              Animals
# creator_state                             MO                   MI
# creator_country                           US                   US
# title_len                                 68                   49
# description_len                          697                 1184
# creator_description_len                    0                    0
# goal                                    5000                 2500
# calculated_goal                         5000                 2500
# is_verified_victory                     True                 True
# num_past_victories                         5                   10
# created_at               2010-07-27 13:11:09  2010-07-28 19:20:57
# end_at                   2010-10-25 23:59:59  2010-12-08 23:59:59
# has_image                               True                 True
# num_tags                                   5                    5
# has_video                              False                False
# num_targets                                1                    1
# creator_type                             org                 user
# letter_body_len                         1335                  981
# creator_has_website                     True                 True
# creator_has_twitter                    False                False
# original_locale                        en-US                en-US
# time_range                                90                  133
#
#                                         955                  981   \
# petition_id                            32028                32082
# status                               victory              victory
# category                    Criminal Justice              Animals
# creator_state                             NC                   DC
# creator_country                           US                   US
# title_len                                 43                   34
# description_len                         3919                  513
# creator_description_len                    0                    0
# goal                                    1000                35000
# calculated_goal                         1000                35000
# is_verified_victory                     True                 True
# num_past_victories                         6                    1
# created_at               2010-08-04 07:08:23  2010-08-05 20:58:59
# end_at                   2011-06-29 23:59:59  2010-10-31 23:59:59
# has_image                               True                 True
# num_tags                                   1                    5
# has_video                              False                False
# num_targets                                4                    1
# creator_type                            user                  org
# letter_body_len                         1813                 1210
# creator_has_website                     True                 True
# creator_has_twitter                    False                False
# original_locale                        en-US                en-US
# time_range                               329                   87
#
#                                         1228                 1477  \
# petition_id                            32559                33056
# status                               victory              victory
# category                   Human Trafficking       Women's Rights
# creator_state                             CA                   MN
# creator_country                           US                   US
# title_len                                 37                   92
# description_len                         3027                 3879
# creator_description_len                    0                  126
# goal                                    3000             12010000
# calculated_goal                         3000            1.201e+07
# is_verified_victory                     True                False
# num_past_victories                         1                    1
# created_at               2010-08-25 11:02:01  2010-09-15 13:16:23
# end_at                   2010-09-30 23:59:59  2013-06-12 23:59:59
# has_image                               True                 True
# num_tags                                   2                    5
# has_video                              False                False
# num_targets                                1                    3
# creator_type                             org                 user
# letter_body_len                         2349                 3953
# creator_has_website                     True                 True
# creator_has_twitter                    False                False
# original_locale                        en-US                en-US
# time_range                                36                 1001
#
#                                 ...                          8930  \
# petition_id                     ...                        203770
# status                          ...                       victory
# category                        ...                    Gay Rights
# creator_state                   ...                            NH
# creator_country                 ...                            US
# title_len                       ...                            66
# description_len                 ...                          2075
# creator_description_len         ...                           537
# goal                            ...                        150000
# calculated_goal                 ...                        150000
# is_verified_victory             ...                          True
# num_past_victories              ...                             1
# created_at                      ...           2012-01-06 16:34:52
# end_at                          ...           2012-12-02 23:59:59
# has_image                       ...                          True
# num_tags                        ...                             6
# has_video                       ...                         False
# num_targets                     ...                             1
# creator_type                    ...                          user
# letter_body_len                 ...                          1027
# creator_has_website             ...                          True
# creator_has_twitter             ...                         False
# original_locale                 ...                         en-US
# time_range                      ...                           331
#
#                                         8987                 8990  \
# petition_id                           208337               208410
# status                               victory              victory
# category                        Human Rights     Immigrant Rights
# creator_state                             FL                   PA
# creator_country                           US                   US
# title_len                                 38                   78
# description_len                         8137                  908
# creator_description_len                    0                    0
# goal                                   10000                 2500
# calculated_goal                        10000                 2500
# is_verified_victory                    False                 True
# num_past_victories                         1                    1
# created_at               2012-01-09 19:00:57  2012-01-09 19:58:04
# end_at                   2012-08-17 23:59:59  2013-01-17 23:59:59
# has_image                               True                 True
# num_tags                                   1                    3
# has_video                              False                False
# num_targets                                4                    5
# creator_type                            user                  org
# letter_body_len                         4211                 1459
# creator_has_website                     True                 True
# creator_has_twitter                    False                False
# original_locale                        en-US                en-US
# time_range                               221                  374
#
#                                         9118                 9122  \
# petition_id                           216951               217213
# status                               victory              victory
# category                             Animals     Immigrant Rights
# creator_state                             MI                   AL
# creator_country                           US                   US
# title_len                                 67                   66
# description_len                          882                 1436
# creator_description_len                    0                    0
# goal                                    1500                 1000
# calculated_goal                         1500                 1000
# is_verified_victory                     True                 True
# num_past_victories                         1                    1
# created_at               2012-01-16 01:57:13  2012-01-16 06:13:45
# end_at                   2012-01-31 23:59:59  2012-01-19 23:59:59
# has_image                               True                 True
# num_tags                                   5                    3
# has_video                              False                False
# num_targets                                5                    5
# creator_type                            user                 user
# letter_body_len                         5353                  725
# creator_has_website                     True                False
# creator_has_twitter                    False                False
# original_locale                        en-US                en-US
# time_range                                15                    3
#
#                                         9175                 9240  \
# petition_id                           221322               224944
# status                               victory              victory
# category                             Animals     Immigrant Rights
# creator_state                             CA                   MO
# creator_country                           US                   US
# title_len                                 67                   65
# description_len                         2120                 3586
# creator_description_len                    0                    0
# goal                                   75000                 1000
# calculated_goal                        75000                 1000
# is_verified_victory                     True                 True
# num_past_victories                         1                    1
# created_at               2012-01-18 19:16:04  2012-01-20 19:41:50
# end_at                   2012-07-24 23:59:59  2012-06-30 23:59:59
# has_image                               True                 True
# num_tags                                   5                    1
# has_video                              False                False
# num_targets                                4                    8
# creator_type                            user                 user
# letter_body_len                         1776                 3489
# creator_has_website                     True                False
# creator_has_twitter                    False                False
# original_locale                        en-US                en-US
# time_range                               188                  162
#
#                                         9281                 9286  \
# petition_id                           227998               228081
# status                               victory              victory
# category                             Animals         Human Rights
# creator_state                           None                   OR
# creator_country                           TH                   US
# title_len                                 89                   85
# description_len                         5168                  904
# creator_description_len                  545                    0
# goal                                    1500                 2000
# calculated_goal                         1500                 2000
# is_verified_victory                    False                 True
# num_past_victories                         1                    1
# created_at               2012-01-22 22:27:24  2012-01-22 23:24:17
# end_at                   2012-05-07 23:59:59  2012-03-05 23:59:59
# has_image                               True                 True
# num_tags                                   3                    1
# has_video                              False                False
# num_targets                                6                    3
# creator_type                            user                 user
# letter_body_len                         1206                 3026
# creator_has_website                     True                 True
# creator_has_twitter                    False                False
# original_locale                           th                en-US
# time_range                               106                   43
#
#                                         9373
# petition_id                           233225
# status                               victory
# category                           Education
# creator_state                             NJ
# creator_country                           US
# title_len                                 39
# description_len                         1312
# creator_description_len                    0
# goal                                   15000
# calculated_goal                        15000
# is_verified_victory                     True
# num_past_victories                         1
# created_at               2012-01-26 02:51:35
# end_at                   2012-06-28 23:59:59
# has_image                               True
# num_tags                                   2
# has_video                              False
# num_targets                                5
# creator_type                            user
# letter_body_len                         1457
# creator_has_website                     True
# creator_has_twitter                    False
# original_locale                        en-US
# time_range                               154
#
# [24 rows x 131 columns]

# %% [markdown]
# ## Trying Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.cross_validation import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score

# %%
log_data = data[["status", "title_len", "description_len", "creator_description_len", \
     "goal", "calculated_goal", "num_past_victories", \
     "has_image", "num_tags", "has_video", \
     "num_targets", "letter_body_len", "creator_has_website", \
    "creator_has_twitter", "time_range"]]

# %%
y = log_data.pop("status")

# %%
X= log_data

# %%
X.head()
# Out:
#    title_len  description_len  creator_description_len  goal  calculated_goal  \
# 0         48              781                      962  5000           5000.0
# 1         40             1042                      395   500            500.0
# 2         99             4068                        0   500            500.0
# 3         25             6203                        0   500            500.0
# 4         61             3223                      698   500            500.0
#
#   is_verified_victory  num_past_victories has_image  num_tags has_video  \
# 0               False                 0.0      True         1     False
# 1               False                 0.0      True         1     False
# 2               False                 0.0      True         0     False
# 3               False                 0.0      True         1     False
# 4               False                 0.0      True         2     False
#
#    num_targets  letter_body_len creator_has_website creator_has_twitter  \
# 0            3             1626                True               False
# 1            1             1334                True               False
# 2            5             1923                True               False
# 3            1             2657                True               False
# 4            5             2483                True               False
#
#    time_range
# 0          90
# 1          90
# 2         163
# 3         640
# 4          90

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y.values)

# %%
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
model.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-205-43c560c947b7> in <module>()
# ----> 1 model.predict(X_test)
#
# /Users/natalie/anaconda/lib/python2.7/site-packages/sklearn/linear_model/base.pyc in predict(self, X)
#     266             Predicted class label per sample.
#     267         """
# --> 268         scores = self.decision_function(X)
#     269         if len(scores.shape) == 1:
#     270             indices = (scores > 0).astype(np.int)
#
# /Users/natalie/anaconda/lib/python2.7/site-packages/sklearn/linear_model/base.pyc in decision_function(self, X)
#     242                                  "yet" % {'name': type(self).__name__})
#     243
# --> 244         X = check_array(X, accept_sparse='csr')
#     245
#     246         n_features = self.coef_.shape[1]
#
# /Users/natalie/anaconda/lib/python2.7/site-packages/sklearn/utils/validation.pyc in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     396                              % (array.ndim, estimator_name))
#     397         if force_all_finite:
# --> 398             _assert_all_finite(array)
#     399
#     400     shape_repr = _shape_repr(array.shape)
#
# /Users/natalie/anaconda/lib/python2.7/site-packages/sklearn/utils/validation.pyc in _assert_all_finite(X)
#      52             and not np.isfinite(X).all()):
#      53         raise ValueError("Input contains NaN, infinity"
# ---> 54                          " or a value too large for %r." % X.dtype)
#      55
#      56
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
pd.to_datetime(np.nan)
# Out:
# NaT

# %%
data = read_mongo("changeorg", "us_closed_petitions", {"petition_id": {"$lt": 236494}})
clean_data = clean_data(data)
