# %%
from pymongo import MongoClient
import pandas as pd

# %%
# Get MongoDB
mc = MongoClient()
db = mc["changeorg"]
petitions_col = db["petitions_scraped"]

# %%
df = pd.DataFrame(list(petitions_col.find({})))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10085 entries, 0 to 10084
# Data columns (total 66 columns):
# _id                                10085 non-null object
# ask                                10085 non-null object
# calculated_goal                    10085 non-null int64
# calculated_goal_with_endorsers     9545 non-null float64
# comments_last_page                 10085 non-null bool
# comments_likes                     10085 non-null int64
# created_at                         10085 non-null object
# creator_name                       10085 non-null object
# creator_photo                      6407 non-null object
# description                        10085 non-null object
# discoverable                       10085 non-null bool
# display_title                      10085 non-null object
# displayed_signature_count          10085 non-null int64
# displayed_supporter_count          9545 non-null float64
# document_id                        10085 non-null object
# end_date                           10085 non-null object
# endorsements                       10085 non-null int64
# endorser_count                     9545 non-null float64
# fb_popularity                      10085 non-null int64
# goal                               206 non-null float64
# id                                 10085 non-null int64
# is_organization                    10085 non-null bool
# is_pledge                          10085 non-null bool
# is_verified_victory                10085 non-null bool
# is_victory                         10085 non-null bool
# languages                          10085 non-null object
# last_past_verified_victory_date    60 non-null object
# last_past_victory_date             158 non-null object
# last_update                        4093 non-null object
# letter_body                        10085 non-null object
# links_fb_popularity                10085 non-null float64
# media                              7595 non-null object
# milestones                         10085 non-null int64
# news_coverages                     10085 non-null int64
# num_comments                       10085 non-null int64
# num_past_petitions                 10085 non-null int64
# num_past_verified_victories        10085 non-null int64
# num_past_victories                 10085 non-null int64
# num_responses                      10085 non-null int64
# num_tweets                         10085 non-null int64
# organization                       901 non-null object
# original_locale                    10085 non-null object
# petition_status                    10085 non-null object
# petition_title                     10085 non-null object
# photo                              7595 non-null object
# photo_id                           0 non-null float64
# primary_target                     10085 non-null object
# progress                           10085 non-null float64
# relevant_location                  10084 non-null object
# restricted_location                619 non-null object
# slug                               10085 non-null object
# status                             10085 non-null object
# tags                               10085 non-null object
# targeting_description              10085 non-null object
# targets                            10085 non-null object
# title                              4376 non-null object
# topic                              1510 non-null object
# total_signature_count              10085 non-null int64
# total_supporter_count              9545 non-null float64
# tweets_followers                   10085 non-null int64
# twitter_popularity                 10085 non-null int64
# user                               10085 non-null object
# victory_date                       329 non-null object
# victory_description                1379 non-null object
# video                              489 non-null object
# weekly_signature_count             10085 non-null int64
# dtypes: bool(6), float64(8), int64(18), object(34)
# memory usage: 4.7+ MB

# %%
df.head().T
# Out:
#                                                                                  0  \
# _id                                                       579d958f51f2b8a00721ed50
# ask                              CARTA A\nDiana María Guillén #Senasa\nVicepres...
# calculated_goal                                                                100
# calculated_goal_with_endorsers                                                 100
# comments_last_page                                                            True
# comments_likes                                                                   0
# created_at                                                    2016-01-20T17:00:13Z
# creator_name                                                        Laura Ferreyra
# creator_photo                    {u'url': u'photos/7/ym/fw/qTYMFWijKULoeFi-full...
# description                      <p>CARTA A<br>Diana María Guillén #Senasa<br>V...
# discoverable                                                                  True
# display_title                    CARTA A Diana María Guillén #Senasa Vicepresid...
# displayed_signature_count                                                        1
# displayed_supporter_count                                                        1
# document_id                                                                5590794
# end_date                                                                2016-01-19
# endorsements                                                                     0
# endorser_count                                                                   0
# fb_popularity                                                                    0
# goal                                                                           NaN
# id                                                                         5590794
# is_organization                                                              False
# is_pledge                                                                    False
# is_verified_victory                                                          False
# is_victory                                                                   False
# languages                                                                     [es]
# last_past_verified_victory_date                                               None
# last_past_victory_date                                                        None
# last_update                                                                   None
# letter_body                      CARTA A\nDiana María Guillén #Senasa\nVicepres...
# ...                                                                            ...
# num_past_verified_victories                                                      0
# num_past_victories                                                               0
# num_responses                                                                    0
# num_tweets                                                                       0
# organization                                                                   NaN
# original_locale                                                                 es
# petition_status                                                             closed
# petition_title                   CARTA A\nDiana María Guillén #Senasa\nVicepres...
# photo                                                                         None
# photo_id                                                                       NaN
# primary_target                   {u'publicly_visible': False, u'slug': None, u'...
# progress                                                                         1
# relevant_location                {u'city': None, u'photo_id': None, u'lat': Non...
# restricted_location                                                           None
# slug                             carta-a-diana-maría-guillén-senasa-vicepreside...
# status                                                                      closed
# tags                                                                            []
# targeting_description            CARTA A Diana María Guillén #Senasa Vicepresid...
# targets                          [{u'publicly_visible': False, u'slug': None, u...
# title                                                                         None
# topic                                                                         None
# total_signature_count                                                            1
# total_supporter_count                                                            1
# tweets_followers                                                                 0
# twitter_popularity                                                               0
# user                             {u'website': None, u'city': u'', u'first_name'...
# victory_date                                                                  None
# victory_description
# video                                                                         None
# weekly_signature_count                                                           0
#
#                                                                                  1  \
# _id                                                       579d958f51f2b8a00721ed56
# ask                                                                              S
# calculated_goal                                                                100
# calculated_goal_with_endorsers                                                 100
# comments_last_page                                                            True
# comments_likes                                                                   0
# created_at                                                    2016-01-21T07:15:46Z
# creator_name                                                                 Ms Me
# creator_photo                    {u'url': u'photos/2/cw/cl/nHCwCldKUmQRjVx-full...
# description                                                                     Tg
# discoverable                                                                  True
# display_title                    Federated States of Micronesia State Senate, M...
# displayed_signature_count                                                        1
# displayed_supporter_count                                                        1
# document_id                                                                5597810
# end_date                                                                2016-01-20
# endorsements                                                                     0
# endorser_count                                                                   0
# fb_popularity                                                                    0
# goal                                                                           NaN
# id                                                                         5597810
# is_organization                                                              False
# is_pledge                                                                    False
# is_verified_victory                                                          False
# is_victory                                                                   False
# languages                                                                     [en]
# last_past_verified_victory_date                                               None
# last_past_victory_date                                                        None
# last_update                                                                   None
# letter_body                                              Get Rick Snyder impeached
# ...                                                                            ...
# num_past_verified_victories                                                      0
# num_past_victories                                                               0
# num_responses                                                                    0
# num_tweets                                                                       0
# organization                                                                   NaN
# original_locale                                                              en-US
# petition_status                                                             closed
# petition_title                   Federated States of Micronesia State Senate, M...
# photo                                                                         None
# photo_id                                                                       NaN
# primary_target                   {u'publicly_visible': True, u'slug': u'federat...
# progress                                                                         1
# relevant_location                {u'city': None, u'photo_id': None, u'lat': Non...
# restricted_location                                                           None
# slug                             federated-states-of-micronesia-state-senate-mi...
# status                                                                      closed
# tags                                                                            []
# targeting_description            Federated States of Micronesia State Senate, M...
# targets                          [{u'publicly_visible': True, u'slug': u'federa...
# title                            Federated States of Micronesia State Senate, M...
# topic                                                                         None
# total_signature_count                                                            1
# total_supporter_count                                                            1
# tweets_followers                                                                 0
# twitter_popularity                                                               0
# user                             {u'website': None, u'city': u'', u'first_name'...
# victory_date                                                                  None
# victory_description                                                           None
# video                                                                         None
# weekly_signature_count                                                           0
#
#                                                                                  2  \
# _id                                                       579d958f51f2b8a00721ed57
# ask                              that the blacklivematter group no longer be al...
# calculated_goal                                                                100
# calculated_goal_with_endorsers                                                 100
# comments_last_page                                                            True
# comments_likes                                                                   0
# created_at                                                    2015-08-29T15:45:18Z
# creator_name                                                         michael lacey
# creator_photo                    {u'url': u'photos/8/tm/lf/XFTmlFTUGreDcLr-full...
# description                                                               <p>.</p>
# discoverable                                                                  True
# display_title                    Barack Obama: that the blacklivematter group n...
# displayed_signature_count                                                        1
# displayed_supporter_count                                                        1
# document_id                                                                4091268
# end_date                                                                2015-08-28
# endorsements                                                                     0
# endorser_count                                                                   0
# fb_popularity                                                                    0
# goal                                                                           NaN
# id                                                                         4091268
# is_organization                                                              False
# is_pledge                                                                    False
# is_verified_victory                                                          False
# is_victory                                                                   False
# languages                                                                     [en]
# last_past_verified_victory_date                                               None
# last_past_victory_date                                                        None
# last_update                                                                   None
# letter_body                                                                      .
# ...                                                                            ...
# num_past_verified_victories                                                      0
# num_past_victories                                                               0
# num_responses                                                                    0
# num_tweets                                                                       0
# organization                                                                   NaN
# original_locale                                                              en-US
# petition_status                                                             closed
# petition_title                   Barack Obama: that the blacklivematter group n...
# photo                            {u'url': u'photos/0/dk/fh/vpdKfhiczlwBtqc-full...
# photo_id                                                                       NaN
# primary_target                   {u'publicly_visible': True, u'slug': u'barack-...
# progress                                                                         1
# relevant_location                {u'city': None, u'photo_id': None, u'lat': Non...
# restricted_location                                                           None
# slug                             barack-obama-that-the-blacklivematter-group-no...
# status                                                                      closed
# tags                                                                            []
# targeting_description                                                 Barack Obama
# targets                          [{u'publicly_visible': True, u'slug': u'barack...
# title                            Barack Obama: that the blacklivematter group n...
# topic                                                                         None
# total_signature_count                                                            1
# total_supporter_count                                                            1
# tweets_followers                                                                 0
# twitter_popularity                                                               0
# user                             {u'website': None, u'city': u'columbus', u'fir...
# victory_date                                                                  None
# victory_description                                                           None
# video                                                                         None
# weekly_signature_count                                                           0
#
#                                                                                  3  \
# _id                                                       579d958f51f2b8a00721ed59
# ask                                            Mi Apoyo que se celebre otro juicio
# calculated_goal                                                                100
# calculated_goal_with_endorsers                                                 100
# comments_last_page                                                            True
# comments_likes                                                                   0
# created_at                                                    2016-02-03T08:00:27Z
# creator_name                                       silvia yolanda gomara corredera
# creator_photo                    {u'url': u'photos/7/jc/il/rgJcilbQywzZouF-full...
# description                      Yo me alegraría y toda España y sobretodo sus ...
# discoverable                                                                  True
# display_title                     Tom Apodaca: Mi Apoyo que se celebre otro juicio
# displayed_signature_count                                                        1
# displayed_supporter_count                                                        1
# document_id                                                                5803866
# end_date                                                                2016-02-02
# endorsements                                                                     0
# endorser_count                                                                   0
# fb_popularity                                                                    0
# goal                                                                           NaN
# id                                                                         5803866
# is_organization                                                              False
# is_pledge                                                                    False
# is_verified_victory                                                          False
# is_victory                                                                   False
# languages                                                                     [es]
# last_past_verified_victory_date                                               None
# last_past_victory_date                                                        None
# last_update                                                                   None
# letter_body                                    Mi Apoyo que se celebre otro juicio
# ...                                                                            ...
# num_past_verified_victories                                                      0
# num_past_victories                                                               0
# num_responses                                                                    0
# num_tweets                                                                       0
# organization                                                                   NaN
# original_locale                                                                 es
# petition_status                                                             closed
# petition_title                                 Mi Apoyo que se celebre otro juicio
# photo                                                                         None
# photo_id                                                                       NaN
# primary_target                   {u'publicly_visible': False, u'slug': u'tom-ap...
# progress                                                                         1
# relevant_location                {u'city': None, u'photo_id': None, u'lat': Non...
# restricted_location                                                           None
# slug                               tom-apodaca-mi-apoyo-que-se-celebre-otro-juicio
# status                                                                      closed
# tags                                                                            []
# targeting_description                                                  Tom Apodaca
# targets                          [{u'publicly_visible': False, u'slug': u'tom-a...
# title                                                                         None
# topic                                                                         None
# total_signature_count                                                            1
# total_supporter_count                                                            1
# tweets_followers                                                                 0
# twitter_popularity                                                               0
# user                             {u'website': None, u'city': u'', u'first_name'...
# victory_date                                                                  None
# victory_description
# video                                                                         None
# weekly_signature_count                                                           0
#
#                                                                                  4
# _id                                                       579d959051f2b8a00721ed5d
# ask                                                    to shutdown cartoon network
# calculated_goal                                                                100
# calculated_goal_with_endorsers                                                 100
# comments_last_page                                                            True
# comments_likes                                                                   0
# created_at                                                    2016-01-21T14:00:15Z
# creator_name                                                           louis alves
# creator_photo                    {u'url': u'photos/1/rp/bd/ijrpbdzvaakbPgk-full...
# description                               <p>shutdown cartoon network complely</p>
# discoverable                                                                  True
# display_title                         L. Louise Lucas: to shutdown cartoon network
# displayed_signature_count                                                        1
# displayed_supporter_count                                                        1
# document_id                                                                5600798
# end_date                                                                2016-01-20
# endorsements                                                                     0
# endorser_count                                                                   0
# fb_popularity                                                                    0
# goal                                                                           NaN
# id                                                                         5600798
# is_organization                                                              False
# is_pledge                                                                    False
# is_verified_victory                                                          False
# is_victory                                                                   False
# languages                                                                     [en]
# last_past_verified_victory_date                                               None
# last_past_victory_date                                                        None
# last_update                                                   2016-01-21T14:03:04Z
# letter_body                                            to shutdown cartoon network
# ...                                                                            ...
# num_past_verified_victories                                                      0
# num_past_victories                                                               0
# num_responses                                                                    0
# num_tweets                                                                       0
# organization                                                                   NaN
# original_locale                                                              en-US
# petition_status                                                             closed
# petition_title                                         to shutdown cartoon network
# photo                                                                         None
# photo_id                                                                       NaN
# primary_target                   {u'publicly_visible': False, u'slug': u'l-loui...
# progress                                                                         1
# relevant_location                {u'city': None, u'photo_id': None, u'lat': Non...
# restricted_location                                                           None
# slug                                    l-louise-lucas-to-shutdown-cartoon-network
# status                                                                      closed
# tags                                                                            []
# targeting_description                                              L. Louise Lucas
# targets                          [{u'publicly_visible': False, u'slug': u'l-lou...
# title                                                                         None
# topic                                                                         None
# total_signature_count                                                            1
# total_supporter_count                                                            1
# tweets_followers                                                                 0
# twitter_popularity                                                               0
# user                             {u'website': None, u'city': u'snaville', u'fir...
# victory_date                                                                  None
# victory_description
# video                                                                         None
# weekly_signature_count                                                           0
#
# [66 rows x 5 columns]

# %% [markdown]
# ## ask

# %% [markdown]
# Ask is a summary of what the petition is asking for. It is texts and has not Nans

# %% [markdown]
# ## goal
# Goal seems to be an attribute they used in the past, the most recent data has this field set to None. Calculated goal and calculated_goal_with_endorsers contains the same information, but the second one contains some NaNs.
# We keep "calculated_goal" and drop the other 2

# %%
df[df["goal"].notnull()][["goal", "calculated_goal", "calculated_goal_with_endorsers"]].head()
# Out:
#       goal  calculated_goal  calculated_goal_with_endorsers
# 988    0.0             2500                          2500.0
# 1015   0.0             7500                          7500.0
# 1073   0.0              100                           100.0
# 1075   0.0              100                           100.0
# 1093   0.0             1000                          1000.0

# %%
df.pop("goal")
df.pop("calculated_goal_with_endorsers")
# Out:
# 0           100.0
# 1           100.0
# 2           100.0
# 3           100.0
# 4           100.0
# 5           100.0
# 6           100.0
# 7           100.0
# 8           100.0
# 9           100.0
# 10         2500.0
# 11          100.0
# 12         7500.0
# 13          100.0
# 14          100.0
# 15          100.0
# 16          100.0
# 17          100.0
# 18          200.0
# 19          500.0
# 20          100.0
# 21          100.0
# 22          100.0
# 23          100.0
# 24          100.0
# 25          100.0
# 26          100.0
# 27          100.0
# 28          100.0
# 29          100.0
#            ...
# 10055       100.0
# 10056     25000.0
# 10057       100.0
# 10058       200.0
# 10059       100.0
# 10060       100.0
# 10061     35000.0
# 10062       100.0
# 10063    200000.0
# 10064    200000.0
# 10065       100.0
# 10066       100.0
# 10067       100.0
# 10068     10000.0
# 10069       100.0
# 10070       100.0
# 10071       100.0
# 10072       100.0
# 10073       100.0
# 10074       100.0
# 10075       100.0
# 10076      1000.0
# 10077       100.0
# 10078      1000.0
# 10079       100.0
# 10080       100.0
# 10081       500.0
# 10082       100.0
# 10083       100.0
# 10084       500.0
# Name: calculated_goal_with_endorsers, dtype: float64

# %% [markdown]
# ## comments_last_page

# %% [markdown]
# comments last page is a boolean. This is a feature generated during the data scraping. Some petitions have over 20.000 pages of comments. Instead of counting all of the comments we put a maximum number of pages to scrape and stored a boolean indicating if it was the last page.

# %% [markdown]
# ## comments_likes

# %% [markdown]
# comments_likes is the sum of the likes in the comments of the petition

# %% [markdown]
# ## created_at and end_date

# %% [markdown]
# * created_at is the date when the petition was created. We need to set it to a datetime type instead of an object
# * end_date is the date when the petition campaign ends

# %%
df["end_date"] = pd.to_datetime(df["end_date"])

# %%
df["created_at"] = pd.to_datetime(df["created_at"])

# %% [markdown]
# ## creator_name

# %% [markdown]
# Name of the petition's creator. We drop it since we don't consider the information relevant

# %% [markdown]
# ## creator_photo media photo video

# %% [markdown]
# creator_photo, media and photo is a dictionary with more information. There are some Nans. We keep it like that for now and will do some feature engineering creating a column that indicates if the creator has a photo

# %% [markdown]
# ## description

# %% [markdown]
# Contains de description of the petition. Interesting to do some NLP after the data cleaning

# %% [markdown]
# ## discoverable

# %% [markdown]
# Not sure what this column means, we keep it for now and see if it is significant.

# %%
df[df["discoverable"] == False].head().T
# Out:
#                                                                               1439  \
# _id                                                       579d989051f2b8a007220471
# ask                              Protect North Carolina residents from dangerou...
# calculated_goal                                                                200
# comments_last_page                                                            True
# comments_likes                                                                   0
# created_at                                                     2015-04-20 18:00:28
# creator_name                                   NORTH CAROLINA CONSERVATION NETWORK
# creator_photo                    {u'url': u'photos/1/kn/ym/SNKNYMkCKYrEQeo-full...
# description                      <p>Tell U.S. Senators Richard Burr and Thom Ti...
# discoverable                                                                 False
# display_title                    Protect North Carolina residents from dangerou...
# displayed_signature_count                                                      110
# displayed_supporter_count                                                      110
# document_id                                                                  G6842
# end_date                                                       2016-04-20 00:00:00
# endorsements                                                                     0
# endorser_count                                                                   0
# fb_popularity                                                                    0
# id                                                                         3308951
# is_organization                                                               True
# is_pledge                                                                    False
# is_verified_victory                                                          False
# is_victory                                                                   False
# languages                                                                     [en]
# last_past_verified_victory_date                                               None
# last_past_victory_date                                                        None
# last_update                                                   2015-05-09T07:39:04Z
# letter_body                      Please do not support the Frank R. Lautenberg ...
# links_fb_popularity                                                              0
# media                            {u'url': u'photos/0/rj/vw/YyrjVwwOqFlGqhm-full...
# ...                                                                            ...
# num_past_verified_victories                                                      0
# num_past_victories                                                               0
# num_responses                                                                    0
# num_tweets                                                                       0
# organization                     {u'website': u'http://www.ncconservationnetwor...
# original_locale                                                              en-US
# petition_status                                                             closed
# petition_title                   Protect North Carolina residents from dangerou...
# photo                            {u'url': u'photos/0/rj/vw/YyrjVwwOqFlGqhm-full...
# photo_id                                                                       NaN
# primary_target                   {u'publicly_visible': True, u'slug': u'richard...
# progress                                                                        55
# relevant_location                {u'city': None, u'photo_id': None, u'lat': Non...
# restricted_location                                                           None
# slug                             protect-north-carolina-residents-from-dangerou...
# status                                                                      closed
# tags                                                                            []
# targeting_description                                                 Richard Burr
# targets                          [{u'publicly_visible': True, u'slug': u'richar...
# title                            Protect North Carolina residents from dangerou...
# topic                                                                  environment
# total_signature_count                                                          110
# total_supporter_count                                                          110
# tweets_followers                                                                 0
# twitter_popularity                                                               0
# user                             {u'website': u'', u'city': u'San Francisco', u...
# victory_date                                                                  None
# victory_description
# video                                                                         None
# weekly_signature_count                                                           0
#
#                                                                               1666  \
# _id                                                       579d98fd51f2b8a0072207e2
# ask                              Tell the General Assembly you support high qua...
# calculated_goal                                                               5000
# comments_last_page                                                            True
# comments_likes                                                                   0
# created_at                                                     2015-03-06 20:02:35
# creator_name                                   Maryland Maternity Access Coalition
# creator_photo                    {u'url': u'photos/4/rk/rs/pHrKrSJahrCPxMt-full...
# description                      <p>Tell the Maryland General Assembly you supp...
# discoverable                                                                 False
# display_title                    Tell the General Assembly you support high qua...
# displayed_signature_count                                                     4006
# displayed_supporter_count                                                     4006
# document_id                                                                  G3701
# end_date                                                       2016-03-02 00:00:00
# endorsements                                                                     0
# endorser_count                                                                   0
# fb_popularity                                                                    0
# id                                                                         3015731
# is_organization                                                               True
# is_pledge                                                                    False
# is_verified_victory                                                          False
# is_victory                                                                   False
# languages                                                                     [en]
# last_past_verified_victory_date                                               None
# last_past_victory_date                                                        None
# last_update                                                                   None
# letter_body                      Protect access to high quality maternity care ...
# links_fb_popularity                                                              0
# media                            {u'url': u'photos/8/sj/zv/HVsJzvAIoVKJZdP-full...
# ...                                                                            ...
# num_past_verified_victories                                                      0
# num_past_victories                                                               0
# num_responses                                                                    0
# num_tweets                                                                       0
# organization                     {u'website': u'http://www.mdmaternityaccess.or...
# original_locale                                                              en-US
# petition_status                                                             closed
# petition_title                   Tell the General Assembly you support high qua...
# photo                            {u'url': u'photos/8/sj/zv/HVsJzvAIoVKJZdP-full...
# photo_id                                                                       NaN
# primary_target                   {u'publicly_visible': True, u'slug': u'marylan...
# progress                                                                     80.12
# relevant_location                {u'city': None, u'photo_id': None, u'lat': Non...
# restricted_location              {u'city': None, u'photo_id': None, u'lat': Non...
# slug                             tell-the-general-assembly-you-support-high-qua...
# status                                                                      closed
# tags                                                                            []
# targeting_description                                         Maryland State House
# targets                          [{u'publicly_visible': True, u'slug': u'maryla...
# title                            Tell the General Assembly you support high qua...
# topic                                                                 womensrights
# total_signature_count                                                            0
# total_supporter_count                                                            0
# tweets_followers                                                                 0
# twitter_popularity                                                               0
# user                             {u'website': u'', u'city': u'San Francisco', u...
# victory_date                                                                  None
# victory_description
# video                                                                         None
# weekly_signature_count                                                           0
#
#                                                                               1749  \
# _id                                                       579d992d51f2b8a0072208f6
# ask                              It’s Time for Commonsense Gun Safety Laws in O...
# calculated_goal                                                              15000
# comments_last_page                                                            True
# comments_likes                                                                   0
# created_at                                                     2015-03-07 00:10:33
# creator_name                                   Americans for Responsible Solutions
# creator_photo                    {u'url': u'photos/9/za/iv/EdZAIvojSrccuoS-full...
# description                      <p>Our gun laws are not doing enough to protec...
# discoverable                                                                 False
# display_title                    Background Checks - It’s Time for Commonsense ...
# displayed_signature_count                                                    10094
# displayed_supporter_count                                                    10094
# document_id                                                                  G3836
# end_date                                                       2016-03-07 00:00:00
# endorsements                                                                     0
# endorser_count                                                                   0
# fb_popularity                                                                    0
# id                                                                         3016906
# is_organization                                                               True
# is_pledge                                                                    False
# is_verified_victory                                                           True
# is_victory                                                                    True
# languages                                                                     [en]
# last_past_verified_victory_date                                               None
# last_past_victory_date                                                        None
# last_update                                                   2015-05-20T23:56:41Z
# letter_body                      Somebody is killed with a gun in Oregon every ...
# links_fb_popularity                                                              0
# media                            {u'url': u'photos/1/sb/vz/NgsBvzINlHBgIzs-full...
# ...                                                                            ...
# num_past_verified_victories                                                      0
# num_past_victories                                                               0
# num_responses                                                                    1
# num_tweets                                                                       0
# organization                     {u'website': u'http://americansforresponsibles...
# original_locale                                                              en-US
# petition_status                                                            victory
# petition_title                   Background Checks - It’s Time for Commonsense ...
# photo                            {u'url': u'photos/1/sb/vz/NgsBvzINlHBgIzs-full...
# photo_id                                                                       NaN
# primary_target                   {u'publicly_visible': True, u'slug': u'oregon-...
# progress                                                                   67.2933
# relevant_location                {u'city': None, u'photo_id': None, u'lat': Non...
# restricted_location              {u'city': None, u'photo_id': None, u'lat': Non...
# slug                             background-checks-it-s-time-for-commonsense-gu...
# status                                                                     victory
# tags                             [{u'photo_id': None, u'name': u'violence', u'l...
# targeting_description                                           Oregon State House
# targets                          [{u'publicly_visible': True, u'slug': u'oregon...
# title                            Background Checks - It’s Time for Commonsense ...
# topic                                                                       health
# total_signature_count                                                         1922
# total_supporter_count                                                         1922
# tweets_followers                                                                 0
# twitter_popularity                                                               0
# user                             {u'website': u'', u'city': u'San Francisco', u...
# victory_date                                                            2015-05-20
# victory_description              Thanks to your support, Oregon Governor Kate B...
# video                                                                         None
# weekly_signature_count                                                           0
#
#                                                                               2262  \
# _id                                                       579d99df51f2b8a007220e6a
# ask                                 Demand a Vote on Life-Saving Background Checks
# calculated_goal                                                               7500
# comments_last_page                                                            True
# comments_likes                                                                   0
# created_at                                                     2015-07-29 21:43:02
# creator_name                                              Everytown for Gun Safety
# creator_photo                    {u'url': u'photos/1/vp/js/tsvpjSIeIRKfXcE-full...
# description                      <p>Another movie theater shooting. Another nig...
# discoverable                                                                 False
# display_title                       Demand a Vote on Life-Saving Background Checks
# displayed_signature_count                                                     6481
# displayed_supporter_count                                                     6481
# document_id                                                                3831448
# end_date                                                       2015-08-24 00:00:00
# endorsements                                                                     0
# endorser_count                                                                   0
# fb_popularity                                                                    0
# id                                                                         3831448
# is_organization                                                               True
# is_pledge                                                                    False
# is_verified_victory                                                          False
# is_victory                                                                   False
# languages                                                                     [en]
# last_past_verified_victory_date                                               None
# last_past_victory_date                                                        None
# last_update                                                   2015-08-12T17:16:49Z
# letter_body                      The movie theater shooting in Lafayette, Louis...
# links_fb_popularity                                                              0
# media                            {u'url': u'photos/9/pl/ov/cnplovKVtfgqzjX-full...
# ...                                                                            ...
# num_past_verified_victories                                                      0
# num_past_victories                                                               0
# num_responses                                                                    0
# num_tweets                                                                       0
# organization                     {u'website': u'http://everytown.org/', u'verif...
# original_locale                                                              en-US
# petition_status                                                             closed
# petition_title                      Demand a Vote on Life-Saving Background Checks
# photo                            {u'url': u'photos/9/pl/ov/cnplovKVtfgqzjX-full...
# photo_id                                                                       NaN
# primary_target                   {u'publicly_visible': True, u'slug': u'u-s-hou...
# progress                                                                   86.4133
# relevant_location                {u'city': u'Washington', u'photo_id': None, u'...
# restricted_location              {u'city': None, u'photo_id': None, u'lat': Non...
# slug                                demand-a-vote-on-life-saving-background-checks
# status                                                                      closed
# tags                             [{u'photo_id': None, u'name': u'Gun Safety', u...
# targeting_description                                U.S. House of Representatives
# targets                          [{u'publicly_visible': True, u'slug': u'u-s-ho...
# title                               Demand a Vote on Life-Saving Background Checks
# topic                                                              criminaljustice
# total_signature_count                                                         6481
# total_supporter_count                                                         6481
# tweets_followers                                                                 0
# twitter_popularity                                                               0
# user                             {u'website': None, u'city': u'Brooklyn', u'fir...
# victory_date                                                                  None
# victory_description
# video                                                                         None
# weekly_signature_count                                                           0
#
#                                                                               2294
# _id                                                       579d99ea51f2b8a007220eb7
# ask                              Repeal the law requiring Florida gambling faci...
# calculated_goal                                                                100
# comments_last_page                                                            True
# comments_likes                                                                   0
# created_at                                                     2015-04-02 19:23:01
# creator_name                                                      Marilyn Varnberg
# creator_photo                                                                  NaN
# description                      <p>More than half of the greyhound races held ...
# discoverable                                                                 False
# display_title                    Florida State House, Florida State Senate, Flo...
# displayed_signature_count                                                        1
# displayed_supporter_count                                                      NaN
# document_id                                                                3205936
# end_date                                                       2016-04-02 00:00:00
# endorsements                                                                     0
# endorser_count                                                                 NaN
# fb_popularity                                                                    0
# id                                                                         3205936
# is_organization                                                              False
# is_pledge                                                                    False
# is_verified_victory                                                          False
# is_victory                                                                   False
# languages                                                                     [en]
# last_past_verified_victory_date                                               None
# last_past_victory_date                                                        None
# last_update                                                                   None
# letter_body                      The Florida state dog racing mandate is a lose...
# links_fb_popularity                                                              0
# media                                                                          NaN
# ...                                                                            ...
# num_past_verified_victories                                                      0
# num_past_victories                                                               0
# num_responses                                                                    0
# num_tweets                                                                       0
# organization                                                                   NaN
# original_locale                                                              en-US
# petition_status                                                             closed
# petition_title                   Florida State House, Florida State Senate, Flo...
# photo                                                                         None
# photo_id                                                                       NaN
# primary_target                   {u'publicly_visible': True, u'slug': u'florida...
# progress                                                                         1
# relevant_location                {u'city': None, u'photo_id': None, u'lat': Non...
# restricted_location              {u'city': None, u'photo_id': None, u'lat': Non...
# slug                             florida-state-house-florida-state-senate-flori...
# status                                                                      closed
# tags                                                                            []
# targeting_description                                             Florida Governor
# targets                          [{u'publicly_visible': True, u'slug': u'florid...
# title                            Florida State House, Florida State Senate, Flo...
# topic                                                                         None
# total_signature_count                                                            1
# total_supporter_count                                                          NaN
# tweets_followers                                                                 0
# twitter_popularity                                                               0
# user                             {u'website': None, u'city': u'', u'first_name'...
# victory_date                                                                  None
# victory_description
# video                                                                         None
# weekly_signature_count                                                           0
#
# [64 rows x 5 columns]

# %% [markdown]
# ## display_title and title and petition_title

# %% [markdown]
# As with the goal, title and petition_title seems to be an attribute used in the past, there are a lot of Nan and the ones that contain information have the same information as display_title. So we keep display_title

# %%
df[df["title"].notnull()][["display_title", "title", "petition_title"]].head()
# Out:
#                                        display_title  \
# 1  Federated States of Micronesia State Senate, M...
# 2  Barack Obama: that the blacklivematter group n...
# 5  Pennsylvania State House: Members of the PA Ho...
# 6  city of Thorton, People for the Ethical Treatm...
# 9                We Support Apple vs FBI NO BACKDOOR
#
#                                                title  \
# 1  Federated States of Micronesia State Senate, M...
# 2  Barack Obama: that the blacklivematter group n...
# 5  Pennsylvania State House: Members of the PA Ho...
# 6  city of Thorton, People for the Ethical Treatm...
# 9                We Support Apple vs FBI NO BACKDOOR
#
#                                       petition_title
# 1  Federated States of Micronesia State Senate, M...
# 2  Barack Obama: that the blacklivematter group n...
# 5  Pennsylvania State House: Members of the PA Ho...
# 6  city of Thorton, People for the Ethical Treatm...
# 9                We Support Apple vs FBI NO BACKDOOR

# %%
df.pop("title")
# Out:
# 0                                                     None
# 1        Federated States of Micronesia State Senate, M...
# 2        Barack Obama: that the blacklivematter group n...
# 3                                                     None
# 4                                                     None
# 5        Pennsylvania State House: Members of the PA Ho...
# 6        city of Thorton, People for the Ethical Treatm...
# 7                                                     None
# 8                                                     None
# 9                      We Support Apple vs FBI NO BACKDOOR
# 10       Cyndi Stevenson, Travis Hutson, Florida Govern...
# 11       Joe Donnelly: Stop Carrier from moving jobs to...
# 12       President Obama, share your vision for drug po...
# 13                                                    None
# 14                          congresistas: Un cambio social
# 15                        Karen Bass: Testing the Platform
# 16       Stand up for Traditional Marriage's (man and w...
# 17       Walmart: Stop contributing to massive food was...
# 18       Tell Governor Cuomo to extend Zika testing to ...
# 19       commission@cityoffargo.com: Save the Kinzler H...
# 20                                                    None
# 21       Chris Broadwater: SAY NO TO ELIMINATION OF TEL...
# 22                                                    None
# 23                                                    None
# 24             President of the United States: Clone Obama
# 25                                                    None
# 26                                         Mike Hall: xxxx
# 27                                                    None
# 28       Mitch Landrieu, STOP Roosh V PRO-RAPE Gatherin...
# 29       Maryland State House: Limit property tax asses...
#                                ...
# 10055    Ted Cruz, Texas State Senate, Texas Governor: ...
# 10056    U.S. Senate, U.S. House of Representatives: Re...
# 10057    Senate Select Committee on Aging and Long Term...
# 10058    Greenpoint Residents Fighting for safer inters...
# 10059    Cory Booker, Robert Menendez: Require fake abo...
# 10060                                                 None
# 10061       Preserve the constitutional right to bear arms
# 10062                                                 None
# 10063    Take Action: Time is running out to protect sa...
# 10064    Take Action: Time is running out to protect sa...
# 10065     Andrew Cuomo: Join Me To Make Kids Go To School.
# 10066    President of the United States: Make “Fuck Up ...
# 10067    Jon Tester, Michael Bennet: Thanks for Putting...
# 10068    Nikki Haley: In light of the Charleston Massac...
# 10069                                                 None
# 10070                                                 None
# 10071                                                 None
# 10072                                                 None
# 10073                                                 None
# 10074                                                 None
# 10075                        Change the Laws of Presidency
# 10076                                                 None
# 10077                                                 None
# 10078    Texas State House: Provide air conditioning to...
# 10079    U.S. Senate: Make discretion of the US FLAG Il...
# 10080                                                 None
# 10081    Richard Blumenthal, Chris Murphy, Jim Himes, R...
# 10082                                                 None
# 10083                          bring back 19 kids: britany
# 10084                                                 None
# Name: title, dtype: object

# %%
df.pop("petition_title")
# Out:
# 0        CARTA A\nDiana María Guillén #Senasa\nVicepres...
# 1        Federated States of Micronesia State Senate, M...
# 2        Barack Obama: that the blacklivematter group n...
# 3                      Mi Apoyo que se celebre otro juicio
# 4                              to shutdown cartoon network
# 5        Pennsylvania State House: Members of the PA Ho...
# 6        city of Thorton, People for the Ethical Treatm...
# 7        Que las medidas adoptadas no trasgredan la int...
# 8                                        Lets have school.
# 9                      We Support Apple vs FBI NO BACKDOOR
# 10       Cyndi Stevenson, Travis Hutson, Florida Govern...
# 11       Joe Donnelly: Stop Carrier from moving jobs to...
# 12       President Obama, share your vision for drug po...
# 13       Que esos hermosos adorables animalitos no pier...
# 14                          congresistas: Un cambio social
# 15                        Karen Bass: Testing the Platform
# 16       Stand up for Traditional Marriage's (man and w...
# 17       Walmart: Stop contributing to massive food was...
# 18       Tell Governor Cuomo to extend Zika testing to ...
# 19       commission@cityoffargo.com: Save the Kinzler H...
# 20                                                       3
# 21       Chris Broadwater: SAY NO TO ELIMINATION OF TEL...
# 22                                Better education rights!
# 23       Tesla, stop selling new vehicles until you can...
# 24             President of the United States: Clone Obama
# 25       Illegalize the Unnecessary ban Against Female ...
# 26                                         Mike Hall: xxxx
# 27                                                    cool
# 28       Mitch Landrieu, STOP Roosh V PRO-RAPE Gatherin...
# 29       Maryland State House: Limit property tax asses...
#                                ...
# 10055    Ted Cruz, Texas State Senate, Texas Governor: ...
# 10056    U.S. Senate, U.S. House of Representatives: Re...
# 10057    Senate Select Committee on Aging and Long Term...
# 10058    Greenpoint Residents Fighting for safer inters...
# 10059    Cory Booker, Robert Menendez: Require fake abo...
# 10060                       Smoking in Any Vehicle Illegal
# 10061       Preserve the constitutional right to bear arms
# 10062           Give every single person in the world PS4!
# 10063    Take Action: Time is running out to protect sa...
# 10064    Take Action: Time is running out to protect sa...
# 10065     Andrew Cuomo: Join Me To Make Kids Go To School.
# 10066    President of the United States: Make “Fuck Up ...
# 10067    Jon Tester, Michael Bennet: Thanks for Putting...
# 10068    Nikki Haley: In light of the Charleston Massac...
# 10069    Make Curry play with his mouthguard in or exil...
# 10070                      Review the case of Shona Banda.
# 10071    Update car seat laws to mandate newer safety r...
# 10072    Take the American Flag down from the South Car...
# 10073              need to stop building a mosque in spain
# 10074              need to stop building a mosque in spain
# 10075                        Change the Laws of Presidency
# 10076                                        IMPEACH OBAMA
# 10077                       Impeach President Barack Obama
# 10078    Texas State House: Provide air conditioning to...
# 10079    U.S. Senate: Make discretion of the US FLAG Il...
# 10080                 To make a skatepark at academy field
# 10081    Richard Blumenthal, Chris Murphy, Jim Himes, R...
# 10082    Remove Martin Luther King Jr.'s name from all ...
# 10083                          bring back 19 kids: britany
# 10084    We are asking you to block the parking of the ...
# Name: petition_title, dtype: object

# %% [markdown]
# ## displayed_signature_count total_signature_count

# %% [markdown]
# Signature count. No Nans. Info seems to be redundant, but at some data points the info is slightly different. We keep displayed since it is the one showed.

# %%
df[df["total_signature_count"]!= df["displayed_signature_count"]][["displayed_signature_count", "total_signature_count", "status"]].head()
# Out:
#      displayed_signature_count  total_signature_count   status
# 81                       14806                  13566  victory
# 432                       2891                   2668  victory
# 494                      19432                  15815  victory
# 546                      68842                  35550  victory
# 718                      68842                  33243  victory

# %% [markdown]
# ## displayed_supporter_count total_supporter_count

# %% [markdown]
# Contains some nans, so, since it is a count we will fill it with 0. Redundant info. We keep displayed.

# %%
df["displayed_supporter_count"].fillna(0, inplace=True)

# %%
df[df["total_supporter_count"]!= df["displayed_supporter_count"]][["total_supporter_count", "displayed_supporter_count", "status"]].head()
# Out:
#      total_supporter_count  displayed_supporter_count   status
# 81                 13566.0                    14806.0  victory
# 272                    NaN                        0.0   closed
# 290                    NaN                        0.0   closed
# 318                    NaN                        0.0   closed
# 345                    NaN                        0.0   closed

# %%
df.pop("total_supporter_count")
df.pop("total_signature_count")
# Out:
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1
# 5           16
# 6           86
# 7            1
# 8            1
# 9            1
# 10        2419
# 11           1
# 12        5048
# 13           1
# 14           1
# 15           1
# 16          36
# 17           1
# 18         107
# 19         258
# 20           1
# 21          20
# 22           8
# 23          17
# 24           5
# 25           1
# 26           1
# 27           1
# 28          22
# 29           1
#          ...
# 10055        1
# 10056    17348
# 10057       19
# 10058      157
# 10059        7
# 10060        1
# 10061    33777
# 10062        1
# 10063    14405
# 10064    10105
# 10065       49
# 10066        1
# 10067        4
# 10068     9803
# 10069        1
# 10070        1
# 10071       28
# 10072        2
# 10073        0
# 10074        0
# 10075       12
# 10076      675
# 10077        1
# 10078      655
# 10079        2
# 10080       45
# 10081      335
# 10082        2
# 10083        1
# 10084      214
# Name: total_signature_count, dtype: int64

# %% [markdown]
# ## document_id

# %% [markdown]
# To drop, doesn't seem relevant

# %%
df.pop("document_id")
# Out:
# 0        5590794
# 1        5597810
# 2        4091268
# 3        5803866
# 4        5600798
# 5        6303017
# 6        5589858
# 7        5905506
# 8        5700710
# 9        6103410
# 10       4091588
# 11       6005358
# 12       6206038
# 13       5601586
# 14       5915138
# 15       6303935
# 16       6105698
# 17       4091808
# 18       5812094
# 19       6011590
# 20       5605202
# 21       6207358
# 22       5926090
# 23       5700762
# 24       6305528
# 25       4094420
# 26       6117798
# 27       5700922
# 28       5814622
# 29       6012186
#           ...
# 10055    3465713
# 10056    3465701
# 10057    3471973
# 10058    3469385
# 10059    3388397
# 10060    3559042
# 10061    3477261
# 10062    3487553
# 10063      G5067
# 10064      G5067
# 10065    3565259
# 10066    3567219
# 10067    3569347
# 10068    3607591
# 10069    3579083
# 10070    3636684
# 10071    3638328
# 10072    3638356
# 10073    3639144
# 10074    3639644
# 10075    3739452
# 10076    3741075
# 10077    3643614
# 10078    3741087
# 10079    3739416
# 10080    3745715
# 10081    3744048
# 10082    3747684
# 10083    3753824
# 10084    3640024
# Name: document_id, dtype: object

# %% [markdown]
# ## endorsements and ensorser_count

# %% [markdown]
# endorsements was created during the data collection, contains the same information as endorser_count. But the second one contain Nans instead of 0's. We keep endorsements.

# %%
df[df["endorsements"]!= 0][["endorsements", "endorser_count", "status", "id"]].head()
# Out:
#      endorsements  endorser_count   status       id
# 202             4             4.0  victory  4221268
# 814             5             5.0  victory  4991122

# %% [markdown]
# ## fb_popularity

# %% [markdown]
# Feature generated during data collection. It gets the Facebook Popularity of the petition url. Is the sum of
#         * number of likes of this URL
#         * number of shares of this URL (this includes copy/pasting a link back to Facebook)
#         * number of likes and comments on stories on Facebook about this URL
#         * number of inbox messages containing this URL as an attachment.

# %%
df[df["fb_popularity"]!= 0][["fb_popularity", "status"]].head()
# Out:
# Empty DataFrame
# Columns: [fb_popularity, status]
# Index: []

# %% [markdown]
# looks like we have a bug!

# %% [markdown]
# ## id

# %% [markdown]
# is is the petition id

# %% [markdown]
# ## is_organization organization

# %% [markdown]
# Info collected during the data scraping. Indicates if the petitioner is an organization. We drop organization's name

# %%
df.pop("organization")
# Out:
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# 5        {u'website': u'', u'verification_requested_at'...
# 6                                                      NaN
# 7                                                      NaN
# 8                                                      NaN
# 9                                                      NaN
# 10                                                     NaN
# 11                                                     NaN
# 12       {u'website': u'http://www.SchoolsNotPrisons.or...
# 13       {u'website': u'', u'verification_requested_at'...
# 14                                                     NaN
# 15                                                     NaN
# 16                                                     NaN
# 17                                                     NaN
# 18                                                     NaN
# 19                                                     NaN
# 20                                                     NaN
# 21       {u'website': u'', u'verification_requested_at'...
# 22                                                     NaN
# 23                                                     NaN
# 24                                                     NaN
# 25                                                     NaN
# 26                                                     NaN
# 27                                                     NaN
# 28                                                     NaN
# 29                                                     NaN
#                                ...
# 10055                                                  NaN
# 10056                                                  NaN
# 10057    {u'website': u'', u'verification_requested_at'...
# 10058    {u'website': u'http://www.ststansacademy.org/'...
# 10059                                                  NaN
# 10060                                                  NaN
# 10061    {u'website': u'http://www.ouramericanrevival.c...
# 10062                                                  NaN
# 10063    {u'website': u'http://www.pewtrusts.org', u've...
# 10064    {u'website': u'http://www.pewtrusts.org', u've...
# 10065                                                  NaN
# 10066                                                  NaN
# 10067    {u'website': u'http://westernvaluesproject.org...
# 10068                                                  NaN
# 10069                                                  NaN
# 10070                                                  NaN
# 10071                                                  NaN
# 10072                                                  NaN
# 10073                                                  NaN
# 10074                                                  NaN
# 10075    {u'website': u'http://www.changethelawsofpresi...
# 10076                                                  NaN
# 10077                                                  NaN
# 10078                                                  NaN
# 10079                                                  NaN
# 10080                                                  NaN
# 10081                                                  NaN
# 10082                                                  NaN
# 10083                                                  NaN
# 10084                                                  NaN
# Name: organization, dtype: object

# %%
df[df["is_organization"]== True][["is_organization", "status"]].head()
# Out:
#    is_organization   status
# 5             True   closed
# 12            True   closed
# 13            True   closed
# 21            True  victory
# 49            True  victory

# %% [markdown]
# ## is_pledge

# %% [markdown]
# It tells us if the petition is a pledge or not

# %%
df[df["is_pledge"]== True][["is_pledge", "status"]].head()
# Out:
#      is_pledge  status
# 4135      True  closed
# 7749      True  closed

# %% [markdown]
# ## is_verified_victory and is_victory

# %% [markdown]
# Info collected during web scraping

# %%
df[df["is_victory"]== True][["is_verified_victory", "is_victory"]].head()
# Out:
#    is_verified_victory is_victory
# 6                False       True
# 16               False       True
# 18               False       True
# 21               False       True
# 44               False       True

# %% [markdown]
# ## languages

# %% [markdown]
# Languages of the petition. It is a dictionary structure inside. Needs some feature engineering.

# %%
df["languages"].apply(lambda x: x[0]).unique()
# Out:
# array([u'es', u'en', u'pt', u'it', u'th', u'ja'], dtype=object)

# %% [markdown]
# ## last_past_verified_victory_date last_past_victory_date last_update

# %% [markdown]
# Dates collected during initial data collection. Need to be converted to datetime

# %%
df["last_past_verified_victory_date"] = pd.to_datetime(df["last_past_verified_victory_date"])
df["last_past_victory_date"] = pd.to_datetime(df["last_past_victory_date"])
df["last_update"] = pd.to_datetime(df["last_update"])

# %% [markdown]
# ## letter_body

# %% [markdown]
# Petitions have a letter attached that is the one that will be presented to the target. Needs feature engineering.

# %% [markdown]
# ## links_fb_popularity

# %% [markdown]
# Similar to fb popularity but calculates the popularity of the links inside the text

# %%
df[df["links_fb_popularity"]== True][["links_fb_popularity", "status"]].head()
# Out:
# Empty DataFrame
# Columns: [links_fb_popularity, status]
# Index: []

# %% [markdown]
# We have a bug

# %% [markdown]
# ## milestones news_coverages num_comments num_past_petitions num_past_verified_victories num_past_victories num_responses num_tweets

# %% [markdown]
# Info collected during web scraping.

# %% [markdown]
# ## original_locale

# %% [markdown]
# Locale of the petition. Keep.

# %%
df["original_locale"].unique()
# Out:
# array([u'es', u'en-US', u'es-419', u'en-GB', u'en-CA', u'pt-BR', u'it',
#        u'th', u'es-AR', u'en-IN', u'en-AU', u'ja'], dtype=object)

# %%
df[((df["original_locale"] != 'en-US') & (df["status"]=="victory"))][["original_locale","status", "is_verified_victory","displayed_signature_count", "id"]]
# Out:
#       original_locale   status is_verified_victory  displayed_signature_count  \
# 45              en-GB  victory               False                          4
# 65                 es  victory               False                          3
# 82                 es  victory               False                          4
# 182                es  victory               False                          1
# 284                es  victory               False                          4
# 341                es  victory               False                         84
# 374             pt-BR  victory               False                          2
# 408                es  victory               False                          2
# 471                es  victory               False                          1
# 522             en-CA  victory               False                          1
# 535             en-GB  victory               False                          1
# 553             en-GB  victory               False                          1
# 566             en-CA  victory               False                        689
# 590             en-CA  victory               False                          1
# 657             en-GB  victory               False                          1
# 707                es  victory               False                          1
# 1035           es-419  victory               False                          2
# 2645            en-GB  victory               False                         20
# 4342            en-GB  victory               False                         14
# 7188               es  victory               False                          3
# 9156            en-GB  victory               False                          5
# 10013           en-GB  victory               False                          2
#
#             id
# 45     6139146
# 65     6323426
# 82     5708342
# 182    5681030
# 284    4267796
# 341    4514691
# 374    4518855
# 408    6599630
# 471    4638554
# 522    5016994
# 535    4817778
# 553    5026738
# 566    4562760
# 590    4398228
# 657    5043582
# 707    6676526
# 1035   4892998
# 2645   3130076
# 4342   3052281
# 7188   3467941
# 9156   3650494
# 10013  3774684

# %% [markdown]
# ## primary_target targets

# %% [markdown]
# Contains the information of the primary target. We keep targets since there are all the targets included.

# %%
df.pop("primary_target")
# Out:
# 0        {u'publicly_visible': False, u'slug': None, u'...
# 1        {u'publicly_visible': True, u'slug': u'federat...
# 2        {u'publicly_visible': True, u'slug': u'barack-...
# 3        {u'publicly_visible': False, u'slug': u'tom-ap...
# 4        {u'publicly_visible': False, u'slug': u'l-loui...
# 5        {u'publicly_visible': True, u'slug': u'pennsyl...
# 6        {u'publicly_visible': False, u'slug': u'city-o...
# 7        {u'publicly_visible': False, u'slug': u'andy-a...
# 8        {u'publicly_visible': False, u'slug': u'kasha-...
# 9        {u'publicly_visible': True, u'slug': u'u-s-hou...
# 10       {u'publicly_visible': False, u'slug': u'cyndi-...
# 11       {u'publicly_visible': False, u'slug': u'joe-do...
# 12       {u'publicly_visible': True, u'slug': u'barack-...
# 13       {u'publicly_visible': False, u'slug': u'elijah...
# 14       {u'publicly_visible': False, u'slug': u'congre...
# 15       {u'publicly_visible': False, u'slug': u'karen-...
# 16       {u'publicly_visible': False, u'slug': u'dan-hu...
# 17       {u'publicly_visible': False, u'slug': u'walmar...
# 18       {u'publicly_visible': True, u'slug': u'andrew-...
# 19       {u'publicly_visible': False, u'slug': u'fargo-...
# 20       {u'publicly_visible': False, u'slug': u'lucill...
# 21       {u'publicly_visible': False, u'slug': u'christ...
# 22       {u'publicly_visible': True, u'slug': u'barack-...
# 23       {u'publicly_visible': False, u'slug': u'elon-m...
# 24       {u'publicly_visible': True, u'slug': u'preside...
# 25       {u'publicly_visible': True, u'slug': u'bernie-...
# 26       {u'publicly_visible': False, u'slug': u'mike-h...
# 27       {u'publicly_visible': True, u'slug': u'preside...
# 28       {u'publicly_visible': False, u'slug': u'mitch-...
# 29       {u'publicly_visible': True, u'slug': u'marylan...
#                                ...
# 10055    {u'publicly_visible': True, u'slug': u'texas-s...
# 10056    {u'publicly_visible': True, u'slug': u'u-s-sen...
# 10057    {u'publicly_visible': False, u'slug': u'senate...
# 10058    {u'publicly_visible': True, u'slug': u'daniel-...
# 10059    {u'publicly_visible': True, u'slug': u'cory-bo...
# 10060    {u'publicly_visible': False, u'slug': u'washin...
# 10061    {u'publicly_visible': True, u'slug': u'barack-...
# 10062    {u'publicly_visible': True, u'slug': u'barack-...
# 10063    {u'publicly_visible': False, u'slug': u'depart...
# 10064    {u'publicly_visible': False, u'slug': u'depart...
# 10065    {u'publicly_visible': True, u'slug': u'andrew-...
# 10066    {u'publicly_visible': True, u'slug': u'preside...
# 10067    {u'publicly_visible': False, u'slug': u'jon-te...
# 10068    {u'publicly_visible': False, u'slug': u'nikki-...
# 10069    {u'publicly_visible': True, u'slug': u'barack-...
# 10070    {u'publicly_visible': False, u'slug': u'kansas...
# 10071    {u'publicly_visible': False, u'slug': u'nikki-...
# 10072    {u'publicly_visible': True, u'slug': u'south-c...
# 10073    {u'publicly_visible': False, u'slug': u'timoth...
# 10074    {u'publicly_visible': False, u'slug': u'timoth...
# 10075    {u'publicly_visible': True, u'slug': u'preside...
# 10076    {u'publicly_visible': False, u'slug': u'united...
# 10077    {u'publicly_visible': True, u'slug': u'barack-...
# 10078    {u'publicly_visible': True, u'slug': u'texas-s...
# 10079    {u'publicly_visible': True, u'slug': u'u-s-sen...
# 10080    {u'publicly_visible': True, u'slug': u'rhode-i...
# 10081    {u'publicly_visible': True, u'slug': u'richard...
# 10082    {u'publicly_visible': True, u'slug': u'u-s-sen...
# 10083    {u'publicly_visible': False, u'slug': u'kasha-...
# 10084    {u'publicly_visible': False, u'slug': u'mayor-...
# Name: primary_target, dtype: object

# %% [markdown]
# ## progress

# %% [markdown]
# Indicates the progress of the signature count. We keep it for now but will probably be dropped in the future.

# %% [markdown]
# ## relevant_location and restricted_location

# %% [markdown]
# Contains info about the relevant location for the petition and if it is restricted. Needs feature engineering.

# %% [markdown]
# ## slug

# %% [markdown]
# slug of the url for https://www.change.org/p/congress-pass-the-able-act the slug is congress-pass-the-able-act

# %% [markdown]
# ## tags

# %% [markdown]
# Contains the tags of the petition. Needs feature engineering

# %% [markdown]
# ## targeting_description

# %% [markdown]
# Info is redundant with targets. Drop.

# %%
df.pop("targeting_description")
# Out:
# 0        CARTA A Diana María Guillén #Senasa Vicepresid...
# 1        Federated States of Micronesia State Senate, M...
# 2                                             Barack Obama
# 3                                              Tom Apodaca
# 4                                          L. Louise Lucas
# 5        Pennsylvania State House, Pennsylvania State S...
# 6        City of Thornton, People for the Ethical Treat...
# 7                                              Andy Anders
# 8                                             Kasha Kelley
# 9        U.S. House of Representatives, U.S. Senate, Ba...
# 10       Cyndi Stevenson, Travis Hutson, Florida Govern...
# 11                Joe Donnelly, Gregory Hayes, Chuck Jones
# 12                                            Barack Obama
# 13                                         Elijah Cummings
# 14                                            congresistas
# 15                                              Karen Bass
# 16                                             Dan Huberty
# 17                                 Walmart, Vicky Hartzler
# 18                                            Andrew Cuomo
# 19       Fargo Commissioners, Tim Mahoney, Fargo Forum,...
# 20                                   Lucille Roybal-Allard
# 21       Chris Broadwater, Rick Edmonds, James Morris, ...
# 22                                          Michelle Obama
# 23                      Elon Musk, Mike Honda, JB Straubel
# 24       President of the United States, Barack Obama, ...
# 25                                          Bernie Sanders
# 26                                               Mike Hall
# 27                          President of the United States
# 28       Mitch Landrieu, Louisiana State House, Louisia...
# 29             Maryland State House, Maryland State Senate
#                                ...
# 10055         Ted Cruz, Texas State Senate, Texas Governor
# 10056           U.S. Senate, U.S. House of Representatives
# 10057    Senate Select Committee on Aging and Long Term...
# 10058    Daniel Squadron, Joseph Lentol, Keith Bray, St...
# 10059                         Cory Booker, Robert Menendez
# 10060                       Washington State, Barack Obama
# 10061                                 Washington Democrats
# 10062                                         Barack Obama
# 10063    Department of the Interior, Secretary Sally Je...
# 10064    Department of the Interior, Secretary Sally Je...
# 10065                                         Andrew Cuomo
# 10066                       President of the United States
# 10067                           Jon Tester, Michael Bennet
# 10068                                          Nikki Haley
# 10069                                         Barack Obama
# 10070                                      Kansas Governor
# 10071    Nikki Haley, South Carolina State Senate, Sout...
# 10072    South Carolina State House, South Carolina Sta...
# 10073                                    Timothy Theriault
# 10074                                    Timothy Theriault
# 10075         President of the United States, Barack Obama
# 10076    United States Citizens, United States Congress...
# 10077    Barack Obama, U.S. House of Representatives, U...
# 10078    Texas State House, Texas State Senate, Texas G...
# 10079                                          U.S. Senate
# 10080                             Rhode Island State House
# 10081    Richard Blumenthal, Chris Murphy, Jim Himes, R...
# 10082                                          U.S. Senate
# 10083       Kasha Kelley, Michael Moon, Brittany Pettersen
# 10084    Mayor Joe Ford, Iaeger, WV, Earl Tomblin, Joe ...
# Name: targeting_description, dtype: object

# %% [markdown]
# ## topic

# %% [markdown]
# It has a lot of Nans, we keep it for now but I think it will be redundant with tags or NLP. Needs feature engineering.

# %% [markdown]
# ## tweets_followers

# %% [markdown]
# number of followers of the embedded tweets

# %%
df[df["tweets_followers"]> 0][["tweets_followers", "status"]].head()
# Out:
#      tweets_followers   status
# 81              36857  victory
# 114             11407  victory
# 139              7822  victory
# 155              4301   closed
# 202           2149688  victory

# %% [markdown]
# ## twitter_popularity

# %% [markdown]
# count of likes and shares of embedded tweets

# %%
df[df["twitter_popularity"]> 0][["twitter_popularity", "status"]].head()
# Out:
#      twitter_popularity   status
# 155                   1   closed
# 202                 365  victory
# 355                4356  victory
# 415                  10   closed
# 500                  38  victory

# %% [markdown]
# ## victory_description victory_date weekly_signature_count photo_id

# %% [markdown]
# Drop.

# %%
df.pop("victory_description")
df.pop("victory_date")
df.pop("weekly_signature_count")
df.pop("photo_id")
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
# 6       NaN
# 7       NaN
# 8       NaN
# 9       NaN
# 10      NaN
# 11      NaN
# 12      NaN
# 13      NaN
# 14      NaN
# 15      NaN
# 16      NaN
# 17      NaN
# 18      NaN
# 19      NaN
# 20      NaN
# 21      NaN
# 22      NaN
# 23      NaN
# 24      NaN
# 25      NaN
# 26      NaN
# 27      NaN
# 28      NaN
# 29      NaN
#          ..
# 10055   NaN
# 10056   NaN
# 10057   NaN
# 10058   NaN
# 10059   NaN
# 10060   NaN
# 10061   NaN
# 10062   NaN
# 10063   NaN
# 10064   NaN
# 10065   NaN
# 10066   NaN
# 10067   NaN
# 10068   NaN
# 10069   NaN
# 10070   NaN
# 10071   NaN
# 10072   NaN
# 10073   NaN
# 10074   NaN
# 10075   NaN
# 10076   NaN
# 10077   NaN
# 10078   NaN
# 10079   NaN
# 10080   NaN
# 10081   NaN
# 10082   NaN
# 10083   NaN
# 10084   NaN
# Name: photo_id, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10085 entries, 0 to 10084
# Data columns (total 52 columns):
# _id                                10085 non-null object
# ask                                10085 non-null object
# calculated_goal                    10085 non-null int64
# comments_last_page                 10085 non-null bool
# comments_likes                     10085 non-null int64
# created_at                         10085 non-null datetime64[ns]
# creator_name                       10085 non-null object
# creator_photo                      6407 non-null object
# description                        10085 non-null object
# discoverable                       10085 non-null bool
# display_title                      10085 non-null object
# displayed_signature_count          10085 non-null int64
# displayed_supporter_count          10085 non-null float64
# end_date                           10085 non-null datetime64[ns]
# endorsements                       10085 non-null int64
# endorser_count                     9545 non-null float64
# fb_popularity                      10085 non-null int64
# id                                 10085 non-null int64
# is_organization                    10085 non-null bool
# is_pledge                          10085 non-null bool
# is_verified_victory                10085 non-null bool
# is_victory                         10085 non-null bool
# languages                          10085 non-null object
# last_past_verified_victory_date    60 non-null datetime64[ns]
# last_past_victory_date             158 non-null datetime64[ns]
# last_update                        4093 non-null datetime64[ns]
# letter_body                        10085 non-null object
# links_fb_popularity                10085 non-null float64
# media                              7595 non-null object
# milestones                         10085 non-null int64
# news_coverages                     10085 non-null int64
# num_comments                       10085 non-null int64
# num_past_petitions                 10085 non-null int64
# num_past_verified_victories        10085 non-null int64
# num_past_victories                 10085 non-null int64
# num_responses                      10085 non-null int64
# num_tweets                         10085 non-null int64
# original_locale                    10085 non-null object
# petition_status                    10085 non-null object
# photo                              7595 non-null object
# progress                           10085 non-null float64
# relevant_location                  10084 non-null object
# restricted_location                619 non-null object
# slug                               10085 non-null object
# status                             10085 non-null object
# tags                               10085 non-null object
# targets                            10085 non-null object
# topic                              1510 non-null object
# tweets_followers                   10085 non-null int64
# twitter_popularity                 10085 non-null int64
# user                               10085 non-null object
# video                              489 non-null object
# dtypes: bool(6), datetime64[ns](5), float64(4), int64(16), object(21)
# memory usage: 3.6+ MB

# %%
df.shape
# Out:
# (10085, 52)

# %%
df.head().T
# Out:
#                                                                                  0  \
# _id                                                       579d958f51f2b8a00721ed50
# ask                              CARTA A\nDiana María Guillén #Senasa\nVicepres...
# calculated_goal                                                                100
# comments_last_page                                                            True
# comments_likes                                                                   0
# created_at                                                     2016-01-20 17:00:13
# creator_name                                                        Laura Ferreyra
# creator_photo                    {u'url': u'photos/7/ym/fw/qTYMFWijKULoeFi-full...
# description                      <p>CARTA A<br>Diana María Guillén #Senasa<br>V...
# discoverable                                                                  True
# display_title                    CARTA A Diana María Guillén #Senasa Vicepresid...
# displayed_signature_count                                                        1
# displayed_supporter_count                                                        1
# end_date                                                       2016-01-19 00:00:00
# endorsements                                                                     0
# endorser_count                                                                   0
# fb_popularity                                                                    0
# id                                                                         5590794
# is_organization                                                              False
# is_pledge                                                                    False
# is_verified_victory                                                          False
# is_victory                                                                   False
# languages                                                                     [es]
# last_past_verified_victory_date                                                NaT
# last_past_victory_date                                                         NaT
# last_update                                                                    NaT
# letter_body                      CARTA A\nDiana María Guillén #Senasa\nVicepres...
# links_fb_popularity                                                              0
# media                                                                          NaN
# milestones                                                                       0
# news_coverages                                                                   0
# num_comments                                                                     0
# num_past_petitions                                                               0
# num_past_verified_victories                                                      0
# num_past_victories                                                               0
# num_responses                                                                    0
# num_tweets                                                                       0
# original_locale                                                                 es
# petition_status                                                             closed
# photo                                                                         None
# progress                                                                         1
# relevant_location                {u'city': None, u'photo_id': None, u'lat': Non...
# restricted_location                                                           None
# slug                             carta-a-diana-maría-guillén-senasa-vicepreside...
# status                                                                      closed
# tags                                                                            []
# targets                          [{u'publicly_visible': False, u'slug': None, u...
# topic                                                                         None
# tweets_followers                                                                 0
# twitter_popularity                                                               0
# user                             {u'website': None, u'city': u'', u'first_name'...
# video                                                                         None
#
#                                                                                  1  \
# _id                                                       579d958f51f2b8a00721ed56
# ask                                                                              S
# calculated_goal                                                                100
# comments_last_page                                                            True
# comments_likes                                                                   0
# created_at                                                     2016-01-21 07:15:46
# creator_name                                                                 Ms Me
# creator_photo                    {u'url': u'photos/2/cw/cl/nHCwCldKUmQRjVx-full...
# description                                                                     Tg
# discoverable                                                                  True
# display_title                    Federated States of Micronesia State Senate, M...
# displayed_signature_count                                                        1
# displayed_supporter_count                                                        1
# end_date                                                       2016-01-20 00:00:00
# endorsements                                                                     0
# endorser_count                                                                   0
# fb_popularity                                                                    0
# id                                                                         5597810
# is_organization                                                              False
# is_pledge                                                                    False
# is_verified_victory                                                          False
# is_victory                                                                   False
# languages                                                                     [en]
# last_past_verified_victory_date                                                NaT
# last_past_victory_date                                                         NaT
# last_update                                                                    NaT
# letter_body                                              Get Rick Snyder impeached
# links_fb_popularity                                                              0
# media                                                                          NaN
# milestones                                                                       0
# news_coverages                                                                   0
# num_comments                                                                     0
# num_past_petitions                                                               0
# num_past_verified_victories                                                      0
# num_past_victories                                                               0
# num_responses                                                                    0
# num_tweets                                                                       0
# original_locale                                                              en-US
# petition_status                                                             closed
# photo                                                                         None
# progress                                                                         1
# relevant_location                {u'city': None, u'photo_id': None, u'lat': Non...
# restricted_location                                                           None
# slug                             federated-states-of-micronesia-state-senate-mi...
# status                                                                      closed
# tags                                                                            []
# targets                          [{u'publicly_visible': True, u'slug': u'federa...
# topic                                                                         None
# tweets_followers                                                                 0
# twitter_popularity                                                               0
# user                             {u'website': None, u'city': u'', u'first_name'...
# video                                                                         None
#
#                                                                                  2  \
# _id                                                       579d958f51f2b8a00721ed57
# ask                              that the blacklivematter group no longer be al...
# calculated_goal                                                                100
# comments_last_page                                                            True
# comments_likes                                                                   0
# created_at                                                     2015-08-29 15:45:18
# creator_name                                                         michael lacey
# creator_photo                    {u'url': u'photos/8/tm/lf/XFTmlFTUGreDcLr-full...
# description                                                               <p>.</p>
# discoverable                                                                  True
# display_title                    Barack Obama: that the blacklivematter group n...
# displayed_signature_count                                                        1
# displayed_supporter_count                                                        1
# end_date                                                       2015-08-28 00:00:00
# endorsements                                                                     0
# endorser_count                                                                   0
# fb_popularity                                                                    0
# id                                                                         4091268
# is_organization                                                              False
# is_pledge                                                                    False
# is_verified_victory                                                          False
# is_victory                                                                   False
# languages                                                                     [en]
# last_past_verified_victory_date                                                NaT
# last_past_victory_date                                                         NaT
# last_update                                                                    NaT
# letter_body                                                                      .
# links_fb_popularity                                                              0
# media                            {u'url': u'photos/0/dk/fh/vpdKfhiczlwBtqc-full...
# milestones                                                                       0
# news_coverages                                                                   0
# num_comments                                                                     0
# num_past_petitions                                                               0
# num_past_verified_victories                                                      0
# num_past_victories                                                               0
# num_responses                                                                    0
# num_tweets                                                                       0
# original_locale                                                              en-US
# petition_status                                                             closed
# photo                            {u'url': u'photos/0/dk/fh/vpdKfhiczlwBtqc-full...
# progress                                                                         1
# relevant_location                {u'city': None, u'photo_id': None, u'lat': Non...
# restricted_location                                                           None
# slug                             barack-obama-that-the-blacklivematter-group-no...
# status                                                                      closed
# tags                                                                            []
# targets                          [{u'publicly_visible': True, u'slug': u'barack...
# topic                                                                         None
# tweets_followers                                                                 0
# twitter_popularity                                                               0
# user                             {u'website': None, u'city': u'columbus', u'fir...
# video                                                                         None
#
#                                                                                  3  \
# _id                                                       579d958f51f2b8a00721ed59
# ask                                            Mi Apoyo que se celebre otro juicio
# calculated_goal                                                                100
# comments_last_page                                                            True
# comments_likes                                                                   0
# created_at                                                     2016-02-03 08:00:27
# creator_name                                       silvia yolanda gomara corredera
# creator_photo                    {u'url': u'photos/7/jc/il/rgJcilbQywzZouF-full...
# description                      Yo me alegraría y toda España y sobretodo sus ...
# discoverable                                                                  True
# display_title                     Tom Apodaca: Mi Apoyo que se celebre otro juicio
# displayed_signature_count                                                        1
# displayed_supporter_count                                                        1
# end_date                                                       2016-02-02 00:00:00
# endorsements                                                                     0
# endorser_count                                                                   0
# fb_popularity                                                                    0
# id                                                                         5803866
# is_organization                                                              False
# is_pledge                                                                    False
# is_verified_victory                                                          False
# is_victory                                                                   False
# languages                                                                     [es]
# last_past_verified_victory_date                                                NaT
# last_past_victory_date                                                         NaT
# last_update                                                                    NaT
# letter_body                                    Mi Apoyo que se celebre otro juicio
# links_fb_popularity                                                              0
# media                                                                          NaN
# milestones                                                                       0
# news_coverages                                                                   0
# num_comments                                                                     0
# num_past_petitions                                                               0
# num_past_verified_victories                                                      0
# num_past_victories                                                               0
# num_responses                                                                    0
# num_tweets                                                                       0
# original_locale                                                                 es
# petition_status                                                             closed
# photo                                                                         None
# progress                                                                         1
# relevant_location                {u'city': None, u'photo_id': None, u'lat': Non...
# restricted_location                                                           None
# slug                               tom-apodaca-mi-apoyo-que-se-celebre-otro-juicio
# status                                                                      closed
# tags                                                                            []
# targets                          [{u'publicly_visible': False, u'slug': u'tom-a...
# topic                                                                         None
# tweets_followers                                                                 0
# twitter_popularity                                                               0
# user                             {u'website': None, u'city': u'', u'first_name'...
# video                                                                         None
#
#                                                                                  4
# _id                                                       579d959051f2b8a00721ed5d
# ask                                                    to shutdown cartoon network
# calculated_goal                                                                100
# comments_last_page                                                            True
# comments_likes                                                                   0
# created_at                                                     2016-01-21 14:00:15
# creator_name                                                           louis alves
# creator_photo                    {u'url': u'photos/1/rp/bd/ijrpbdzvaakbPgk-full...
# description                               <p>shutdown cartoon network complely</p>
# discoverable                                                                  True
# display_title                         L. Louise Lucas: to shutdown cartoon network
# displayed_signature_count                                                        1
# displayed_supporter_count                                                        1
# end_date                                                       2016-01-20 00:00:00
# endorsements                                                                     0
# endorser_count                                                                   0
# fb_popularity                                                                    0
# id                                                                         5600798
# is_organization                                                              False
# is_pledge                                                                    False
# is_verified_victory                                                          False
# is_victory                                                                   False
# languages                                                                     [en]
# last_past_verified_victory_date                                                NaT
# last_past_victory_date                                                         NaT
# last_update                                                    2016-01-21 14:03:04
# letter_body                                            to shutdown cartoon network
# links_fb_popularity                                                              0
# media                                                                          NaN
# milestones                                                                       0
# news_coverages                                                                   1
# num_comments                                                                     0
# num_past_petitions                                                               1
# num_past_verified_victories                                                      0
# num_past_victories                                                               0
# num_responses                                                                    0
# num_tweets                                                                       0
# original_locale                                                              en-US
# petition_status                                                             closed
# photo                                                                         None
# progress                                                                         1
# relevant_location                {u'city': None, u'photo_id': None, u'lat': Non...
# restricted_location                                                           None
# slug                                    l-louise-lucas-to-shutdown-cartoon-network
# status                                                                      closed
# tags                                                                            []
# targets                          [{u'publicly_visible': False, u'slug': u'l-lou...
# topic                                                                         None
# tweets_followers                                                                 0
# twitter_popularity                                                               0
# user                             {u'website': None, u'city': u'snaville', u'fir...
# video                                                                         None

# %% [markdown]
# ------------------------

# %%
def relevant_country(location):
    if location is not None:
        return location["country_code"]
    else:
        return None

# %%
df["relevant_country"]=df["relevant_location"].apply(lambda x: relevant_country(x))

# %%
    def relevant_state(location):
        if location is not None:
            return location["state_code"]
        else:
            return None

# %%
df["relevant_state"] = df["relevant_location"].apply(lambda x: relevant_state(x))

# %%
df["user_country"] = df["user"].apply(lambda x: x["country_code"])

# %%
df["user_state"] = df["user"].apply(lambda x: x["state_code"])

# %%
df[df["relevant_state"].isnull()].count()
# Out:
# _id                                9770
# ask                                9770
# calculated_goal                    9770
# comments_last_page                 9770
# comments_likes                     9770
# created_at                         9770
# creator_name                       9770
# creator_photo                      6152
# description                        9770
# discoverable                       9770
# display_title                      9770
# displayed_signature_count          9770
# displayed_supporter_count          9770
# end_date                           9770
# endorsements                       9770
# endorser_count                     9243
# fb_popularity                      9770
# id                                 9770
# is_organization                    9770
# is_pledge                          9770
# is_verified_victory                9770
# is_victory                         9770
# languages                          9770
# last_past_verified_victory_date      48
# last_past_victory_date              127
# last_update                        3791
# letter_body                        9770
# links_fb_popularity                9770
# media                              7300
# milestones                         9770
# news_coverages                     9770
# num_comments                       9770
# num_past_petitions                 9770
# num_past_verified_victories        9770
# num_past_victories                 9770
# num_responses                      9770
# num_tweets                         9770
# original_locale                    9770
# petition_status                    9770
# photo                              7300
# progress                           9770
# relevant_location                  9769
# restricted_location                 533
# slug                               9770
# status                             9770
# tags                               9770
# targets                            9770
# topic                              1391
# tweets_followers                   9770
# twitter_popularity                 9770
# user                               9770
# video                               474
# relevant_country                   9769
# relevant_state                        0
# user_country                       9770
# user_state                         8893
# dtype: int64

# %%
def target_states(targets):
    states = []
    titles = []
    names = []
    for target in targets:
        if target["type"] == "Politician":
            states.append(target["additional_data"]["state"])
            titles.append(target["additional_data"]["title"])
            names.append(target["display_name"])
    return states, titles, names

# %%
df["targets"].apply(lambda x: target_states(x))
# Out:
# 0                   ([NC], [Representative], [Alma Adams])
# 1                    ([None], [President], [Barack Obama])
# 2                    ([None], [President], [Barack Obama])
# 3                   ([NC], [State Senator], [Tom Apodaca])
# 4        ([VA, NC], [State Senator, State Senator], [L....
# 5                                             ([], [], [])
# 6                  ([CO], [Governor], [John Hickenlooper])
# 7            ([LA], [State Representative], [Andy Anders])
# 8           ([KS], [State Representative], [Kasha Kelley])
# 9                    ([None], [President], [Barack Obama])
# 10       ([FL, FL, FL, FL], [State Representative, Stat...
# 11                       ([IN], [Senator], [Joe Donnelly])
# 12                   ([None], [President], [Barack Obama])
# 13             ([MD], [Representative], [Elijah Cummings])
# 14         ([WA], [State Representative], [Sharon Santos])
# 15                  ([CA], [Representative], [Karen Bass])
# 16           ([TX], [State Representative], [Dan Huberty])
# 17              ([MO], [Representative], [Vicky Hartzler])
# 18                      ([NY], [Governor], [Andrew Cuomo])
# 19       ([ND, ND], [Senator, Senator], [John Hoeven, H...
# 20       ([CA], [Representative], [Lucille Roybal-Allard])
# 21       ([LA, LA, LA], [State Representative, State Re...
# 22                   ([None], [President], [Barack Obama])
# 23                  ([CA], [Representative], [Mike Honda])
# 24                   ([None], [President], [Barack Obama])
# 25       ([VT, VT], [Senator, Senator], [Bernie Sanders...
# 26                    ([WV], [State Senator], [Mike Hall])
# 27                                            ([], [], [])
# 28       ([LA, LA], [Senator, Governor], [David Vitter,...
# 29                                            ([], [], [])
#                                ...
# 10055                                         ([], [], [])
# 10056                                         ([], [], [])
# 10057    ([CA, CA], [State Senator, State Senator], [Ca...
# 10058    ([NY, NY], [State Senator, State Representativ...
# 10059    ([NJ, NJ], [Senator, Senator], [Cory Booker, R...
# 10060                ([None], [President], [Barack Obama])
# 10061                ([None], [President], [Barack Obama])
# 10062                ([None], [President], [Barack Obama])
# 10063                                         ([], [], [])
# 10064                                         ([], [], [])
# 10065                   ([NY], [Governor], [Andrew Cuomo])
# 10066                                         ([], [], [])
# 10067    ([MT, CO], [Senator, Senator], [Jon Tester, Mi...
# 10068                    ([SC], [Governor], [Nikki Haley])
# 10069                ([None], [President], [Barack Obama])
# 10070                                         ([], [], [])
# 10071                    ([SC], [Governor], [Nikki Haley])
# 10072                                         ([], [], [])
# 10073    ([ME], [State Representative], [Timothy Theria...
# 10074    ([ME], [State Representative], [Timothy Theria...
# 10075                ([None], [President], [Barack Obama])
# 10076                                         ([], [], [])
# 10077                ([None], [President], [Barack Obama])
# 10078                                         ([], [], [])
# 10079                                         ([], [], [])
# 10080                                         ([], [], [])
# 10081    ([CT, CT, CT, CT, CT, CT, CT], [Senator, Senat...
# 10082                                         ([], [], [])
# 10083    ([KS, MO, CO], [State Representative, State Re...
# 10084    ([WV, WV, WV], [Governor, Senator, Senator], [...
# Name: targets, dtype: object

# %%
d = {
    "city": "Washington",
    "country_code": "US",
    "lat": None,
    "lng": None,
    "state_code": "DC",
    "google_places_id": None,
    "photo_id": None
  }

# %%
df["topic"].unique()
# Out:
# array([u'environment', u'humanrights', None, u'criminaljustice',
#        u'economicjustice', u'animals', u'health', u'education',
#        u'gayrights', u'immigration', u'womensrights', u'',
#        u'humantrafficking', u'food', u'socialentrepreneurship',
#        u'globalpoverty', u'race', u'homelessness'], dtype=object)

# %%
df[["targets", "id"]].head()
# Out:
#                                              targets       id
# 0  [{u'publicly_visible': False, u'slug': None, u...  5590794
# 1  [{u'publicly_visible': True, u'slug': u'federa...  5597810
# 2  [{u'publicly_visible': True, u'slug': u'barack...  4091268
# 3  [{u'publicly_visible': False, u'slug': u'tom-a...  5803866
# 4  [{u'publicly_visible': False, u'slug': u'l-lou...  5600798

# %% [markdown]
# # removing trolls

# %%
df[(df['status'] == "closed") | ((df['status'] =="victory") & (df['displayed_signature_count'] >100))].T
# Out:
#                                                                              0      \
# _id                                                       579d958f51f2b8a00721ed50
# ask                              CARTA A\nDiana María Guillén #Senasa\nVicepres...
# calculated_goal                                                                100
# comments_last_page                                                            True
# comments_likes                                                                   0
# created_at                                                     2016-01-20 17:00:13
# creator_name                                                        Laura Ferreyra
# creator_photo                    {u'url': u'photos/7/ym/fw/qTYMFWijKULoeFi-full...
# description                      <p>CARTA A<br>Diana María Guillén #Senasa<br>V...
# discoverable                                                                  True
# display_title                    CARTA A Diana María Guillén #Senasa Vicepresid...
# displayed_signature_count                                                        1
# displayed_supporter_count                                                        1
# end_date                                                       2016-01-19 00:00:00
# endorsements                                                                     0
# endorser_count                                                                   0
# fb_popularity                                                                    0
# id                                                                         5590794
# is_organization                                                              False
# is_pledge                                                                    False
# is_verified_victory                                                          False
# is_victory                                                                   False
# languages                                                                     [es]
# last_past_verified_victory_date                                                NaT
# last_past_victory_date                                                         NaT
# last_update                                                                    NaT
# letter_body                      CARTA A\nDiana María Guillén #Senasa\nVicepres...
# links_fb_popularity                                                              0
# media                                                                          NaN
# milestones                                                                       0
# news_coverages                                                                   0
# num_comments                                                                     0
# num_past_petitions                                                               0
# num_past_verified_victories                                                      0
# num_past_victories                                                               0
# num_responses                                                                    0
# num_tweets                                                                       0
# original_locale                                                                 es
# petition_status                                                             closed
# photo                                                                         None
# progress                                                                         1
# relevant_location                {u'city': None, u'photo_id': None, u'lat': Non...
# restricted_location                                                           None
# slug                             carta-a-diana-maría-guillén-senasa-vicepreside...
# status                                                                      closed
# tags                                                                            []
# targets                          [{u'publicly_visible': False, u'slug': None, u...
# topic                                                                         None
# tweets_followers                                                                 0
# twitter_popularity                                                               0
# user                             {u'website': None, u'city': u'', u'first_name'...
# video                                                                         None
# relevant_country                                                                AR
#
#                                                                              1      \
# _id                                                       579d958f51f2b8a00721ed56
# ask                                                                              S
# calculated_goal                                                                100
# comments_last_page                                                            True
# comments_likes                                                                   0
# created_at                                                     2016-01-21 07:15:46
# creator_name                                                                 Ms Me
# creator_photo                    {u'url': u'photos/2/cw/cl/nHCwCldKUmQRjVx-full...
# description                                                                     Tg
# discoverable                                                                  True
# display_title                    Federated States of Micronesia State Senate, M...
# displayed_signature_count                                                        1
# displayed_supporter_count                                                        1
# end_date                                                       2016-01-20 00:00:00
# endorsements                                                                     0
# endorser_count                                                                   0
# fb_popularity                                                                    0
# id                                                                         5597810
# is_organization                                                              False
# is_pledge                                                                    False
# is_verified_victory                                                          False
# is_victory                                                                   False
# languages                                                                     [en]
# last_past_verified_victory_date                                                NaT
# last_past_victory_date                                                         NaT
# last_update                                                                    NaT
# letter_body                                              Get Rick Snyder impeached
# links_fb_popularity                                                              0
# media                                                                          NaN
# milestones                                                                       0
# news_coverages                                                                   0
# num_comments                                                                     0
# num_past_petitions                                                               0
# num_past_verified_victories                                                      0
# num_past_victories                                                               0
# num_responses                                                                    0
# num_tweets                                                                       0
# original_locale                                                              en-US
# petition_status                                                             closed
# photo                                                                         None
# progress                                                                         1
# relevant_location                {u'city': None, u'photo_id': None, u'lat': Non...
# restricted_location                                                           None
# slug                             federated-states-of-micronesia-state-senate-mi...
# status                                                                      closed
# tags                                                                            []
# targets                          [{u'publicly_visible': True, u'slug': u'federa...
# topic                                                                         None
# tweets_followers                                                                 0
# twitter_popularity                                                               0
# user                             {u'website': None, u'city': u'', u'first_name'...
# video                                                                         None
# relevant_country                                                                US
#
#                                                                              2      \
# _id                                                       579d958f51f2b8a00721ed57
# ask                              that the blacklivematter group no longer be al...
# calculated_goal                                                                100
# comments_last_page                                                            True
# comments_likes                                                                   0
# created_at                                                     2015-08-29 15:45:18
# creator_name                                                         michael lacey
# creator_photo                    {u'url': u'photos/8/tm/lf/XFTmlFTUGreDcLr-full...
# description                                                               <p>.</p>
# discoverable                                                                  True
# display_title                    Barack Obama: that the blacklivematter group n...
# displayed_signature_count                                                        1
# displayed_supporter_count                                                        1
# end_date                                                       2015-08-28 00:00:00
# endorsements                                                                     0
# endorser_count                                                                   0
# fb_popularity                                                                    0
# id                                                                         4091268
# is_organization                                                              False
# is_pledge                                                                    False
# is_verified_victory                                                          False
# is_victory                                                                   False
# languages                                                                     [en]
# last_past_verified_victory_date                                                NaT
# last_past_victory_date                                                         NaT
# last_update                                                                    NaT
# letter_body                                                                      .
# links_fb_popularity                                                              0
# media                            {u'url': u'photos/0/dk/fh/vpdKfhiczlwBtqc-full...
# milestones                                                                       0
# news_coverages                                                                   0
# num_comments                                                                     0
# num_past_petitions                                                               0
# num_past_verified_victories                                                      0
# num_past_victories                                                               0
# num_responses                                                                    0
# num_tweets                                                                       0
# original_locale                                                              en-US
# petition_status                                                             closed
# photo                            {u'url': u'photos/0/dk/fh/vpdKfhiczlwBtqc-full...
# progress                                                                         1
# relevant_location                {u'city': None, u'photo_id': None, u'lat': Non...
# restricted_location                                                           None
# slug                             barack-obama-that-the-blacklivematter-group-no...
# status                                                                      closed
# tags                                                                            []
# targets                          [{u'publicly_visible': True, u'slug': u'barack...
# topic                                                                         None
# tweets_followers                                                                 0
# twitter_popularity                                                               0
# user                             {u'website': None, u'city': u'columbus', u'fir...
# video                                                                         None
# relevant_country                                                                US
#
#                                                                              3      \
# _id                                                       579d958f51f2b8a00721ed59
# ask                                            Mi Apoyo que se celebre otro juicio
# calculated_goal                                                                100
# comments_last_page                                                            True
# comments_likes                                                                   0
# created_at                                                     2016-02-03 08:00:27
# creator_name                                       silvia yolanda gomara corredera
# creator_photo                    {u'url': u'photos/7/jc/il/rgJcilbQywzZouF-full...
# description                      Yo me alegraría y toda España y sobretodo sus ...
# discoverable                                                                  True
# display_title                     Tom Apodaca: Mi Apoyo que se celebre otro juicio
# displayed_signature_count                                                        1
# displayed_supporter_count                                                        1
# end_date                                                       2016-02-02 00:00:00
# endorsements                                                                     0
# endorser_count                                                                   0
# fb_popularity                                                                    0
# id                                                                         5803866
# is_organization                                                              False
# is_pledge                                                                    False
# is_verified_victory                                                          False
# is_victory                                                                   False
# languages                                                                     [es]
# last_past_verified_victory_date                                                NaT
# last_past_victory_date                                                         NaT
# last_update                                                                    NaT
# letter_body                                    Mi Apoyo que se celebre otro juicio
# links_fb_popularity                                                              0
# media                                                                          NaN
# milestones                                                                       0
# news_coverages                                                                   0
# num_comments                                                                     0
# num_past_petitions                                                               0
# num_past_verified_victories                                                      0
# num_past_victories                                                               0
# num_responses                                                                    0
# num_tweets                                                                       0
# original_locale                                                                 es
# petition_status                                                             closed
# photo                                                                         None
# progress                                                                         1
# relevant_location                {u'city': None, u'photo_id': None, u'lat': Non...
# restricted_location                                                           None
# slug                               tom-apodaca-mi-apoyo-que-se-celebre-otro-juicio
# status                                                                      closed
# tags                                                                            []
# targets                          [{u'publicly_visible': False, u'slug': u'tom-a...
# topic                                                                         None
# tweets_followers                                                                 0
# twitter_popularity                                                               0
# user                             {u'website': None, u'city': u'', u'first_name'...
# video                                                                         None
# relevant_country                                                                ES
#
#                                                                              4      \
# _id                                                       579d959051f2b8a00721ed5d
# ask                                                    to shutdown cartoon network
# calculated_goal                                                                100
# comments_last_page                                                            True
# comments_likes                                                                   0
# created_at                                                     2016-01-21 14:00:15
# creator_name                                                           louis alves
# creator_photo                    {u'url': u'photos/1/rp/bd/ijrpbdzvaakbPgk-full...
# description                               <p>shutdown cartoon network complely</p>
# discoverable                                                                  True
# display_title                         L. Louise Lucas: to shutdown cartoon network
# displayed_signature_count                                                        1
# displayed_supporter_count                                                        1
# end_date                                                       2016-01-20 00:00:00
# endorsements                                                                     0
# endorser_count                                                                   0
# fb_popularity                                                                    0
# id                                                                         5600798
# is_organization                                                              False
# is_pledge                                                                    False
# is_verified_victory                                                          False
# is_victory                                                                   False
# languages                                                                     [en]
# last_past_verified_victory_date                                                NaT
# last_past_victory_date                                                         NaT
# last_update                                                    2016-01-21 14:03:04
# letter_body                                            to shutdown cartoon network
# links_fb_popularity                                                              0
# media                                                                          NaN
# milestones                                                                       0
# news_coverages                                                                   1
# num_comments                                                                     0
# num_past_petitions                                                               1
# num_past_verified_victories                                                      0
# num_past_victories                                                               0
# num_responses                                                                    0
# num_tweets                                                                       0
# original_locale                                                              en-US
# petition_status                                                             closed
# photo                                                                         None
# progress                                                                         1
# relevant_location                {u'city': None, u'photo_id': None, u'lat': Non...
# restricted_location                                                           None
# slug                                    l-louise-lucas-to-shutdown-cartoon-network
# status                                                                      closed
# tags                                                                            []
# targets                          [{u'publicly_visible': False, u'slug': u'l-lou...
# topic                                                                         None
# tweets_followers                                                                 0
# twitter_popularity                                                               0
# user                             {u'website': None, u'city': u'snaville', u'fir...
# video                                                                         None
# relevant_country                                                                US
#
#                                                                              5      \
# _id                                                       579d959051f2b8a00721ed5f
# ask                              Members of the PA House and Senate:  refuse yo...
# calculated_goal                                                                100
# comments_last_page                                                            True
# comments_likes                                                                   1
# created_at                                                     2016-03-01 00:46:51
# creator_name                                     Concerned Citizen of Pennsylvania
# creator_photo                    {u'url': u'photos/1/ud/ie/FQUDiEaFECibmIo-full...
# description                      When we don't do our jobs,  we don't get paid!...
# discoverable                                                                  True
# display_title                    Pennsylvania State House: Members of the PA Ho...
# displayed_signature_count                                                       16
# displayed_supporter_count                                                       16
# end_date                                                       2016-03-15 00:00:00
# endorsements                                                                     0
# endorser_count                                                                   0
# fb_popularity                                                                    0
# id                                                                         6303017
# is_organization                                                               True
# is_pledge                                                                    False
# is_verified_victory                                                          False
# is_victory                                                                   False
# languages                                                                     [en]
# last_past_verified_victory_date                                                NaT
# last_past_victory_date                                                         NaT
# last_update                                                    2016-03-01 04:52:30
# letter_body                      Members of the PA House and Senate to refuse t...
# links_fb_popularity                                                              0
# media                            {u'url': u'photos/3/sj/nl/yzsjnLiTyHhdhZT-full...
# milestones                                                                       2
# news_coverages                                                                   0
# num_comments                                                                     2
# num_past_petitions                                                               0
# num_past_verified_victories                                                      0
# num_past_victories                                                               0
# num_responses                                                                    0
# num_tweets                                                                       0
# original_locale                                                              en-US
# petition_status                                                             closed
# photo                            {u'url': u'photos/3/sj/nl/yzsjnLiTyHhdhZT-full...
# progress                                                                        16
# relevant_location                {u'city': None, u'photo_id': None, u'lat': Non...
# restricted_location                                                           None
# slug                             pennsylvania-state-house-members-of-the-pa-hou...
# status                                                                      closed
# tags                                                                            []
# targets                          [{u'publicly_visible': True, u'slug': u'pennsy...
# topic                                                              economicjustice
# tweets_followers                                                                 0
# twitter_popularity                                                               0
# user                             {u'website': None, u'city': u'Clearfield', u'f...
# video                                                                         None
# relevant_country                                                                US
#
#                                                                              7      \
# _id                                                       579d959051f2b8a00721ed5c
# ask                              Que las medidas adoptadas no trasgredan la int...
# calculated_goal                                                                100
# comments_last_page                                                            True
# comments_likes                                                                   0
# created_at                                                     2016-02-08 15:30:12
# creator_name                                                       Orlando Farrago
# creator_photo                                                                  NaN
# description                      Que La interpretación de los actos no sean par...
# discoverable                                                                  True
# display_title                    Andy Anders: Que las medidas adoptadas no tras...
# displayed_signature_count                                                        1
# displayed_supporter_count                                                        1
# end_date                                                       2016-02-07 00:00:00
# endorsements                                                                     0
# endorser_count                                                                   0
# fb_popularity                                                                    0
# id                                                                         5905506
# is_organization                                                              False
# is_pledge                                                                    False
# is_verified_victory                                                          False
# is_victory                                                                   False
# languages                                                                     [es]
# last_past_verified_victory_date                                                NaT
# last_past_victory_date                                                         NaT
# last_update                                                                    NaT
# letter_body                      Que las medidas adoptadas no trasgredan la int...
# links_fb_popularity                                                              0
# media                                                                          NaN
# milestones                                                                       0
# news_coverages                                                                   0
# num_comments                                                                     0
# num_past_petitions                                                               0
# num_past_verified_victories                                                      0
# num_past_victories                                                               0
# num_responses                                                                    0
# num_tweets                                                                       0
# original_locale                                                                 es
# petition_status                                                             closed
# photo                                                                         None
# progress                                                                         1
# relevant_location                {u'city': None, u'photo_id': None, u'lat': Non...
# restricted_location                                                           None
# slug                             andy-anders-que-las-medidas-adoptadas-no-trasg...
# status                                                                      closed
# tags                                                                            []
# targets                          [{u'publicly_visible': False, u'slug': u'andy-...
# topic                                                                         None
# tweets_followers                                                                 0
# twitter_popularity                                                               0
# user                             {u'website': None, u'city': u'', u'first_name'...
# video                                                                         None
# relevant_country                                                                ES
#
#                                                                              8      \
# _id                                                       579d959051f2b8a00721ed63
# ask                                                              Lets have school.
# calculated_goal                                                                100
# comments_last_page                                                            True
# comments_likes                                                                   0
# created_at                                                     2016-01-27 21:18:30
# creator_name                                                    katherine portillo
# creator_photo                                                                  NaN
# description                      I want there to be school because if there isn...
# discoverable                                                                  True
# display_title                                      Kasha Kelley: Lets have school.
# displayed_signature_count                                                        1
# displayed_supporter_count                                                        1
# end_date                                                       2016-01-26 00:00:00
# endorsements                                                                     0
# endorser_count                                                                   0
# fb_popularity                                                                    0
# id                                                                         5700710
# is_organization                                                              False
# is_pledge                                                                    False
# is_verified_victory                                                          False
# is_victory                                                                   False
# languages                                                                     [en]
# last_past_verified_victory_date                                                NaT
# last_past_victory_date                                                         NaT
# last_update                                                                    NaT
# letter_body                                                      Lets have school.
# links_fb_popularity                                                              0
# media                                                                          NaN
# milestones                                                                       0
# news_coverages                                                                   0
# num_comments                                                                     0
# num_past_petitions                                                               0
# num_past_verified_victories                                                      0
# num_past_victories                                                               0
# num_responses                                                                    0
# num_tweets                                                                       0
# original_locale                                                              en-US
# petition_status                                                             closed
# photo                                                                         None
# progress                                                                         1
# relevant_location                {u'city': None, u'photo_id': None, u'lat': Non...
# restricted_location                                                           None
# slug                                                 kasha-kelley-lets-have-school
# status                                                                      closed
# tags                                                                            []
# targets                          [{u'publicly_visible': False, u'slug': u'kasha...
# topic                                                                         None
# tweets_followers                                                                 0
# twitter_popularity                                                               0
# user                             {u'website': None, u'city': u'', u'first_name'...
# video                                                                         None
# relevant_country                                                                US
#
#                                                                              9      \
# _id                                                       579d959051f2b8a00721ed61
# ask                                            We Support Apple vs FBI NO BACKDOOR
# calculated_goal                                                                100
# comments_last_page                                                            True
# comments_likes                                                                   0
# created_at                                                     2016-02-18 02:02:40
# creator_name                                                           Tom Mahoney
# creator_photo                    {u'url': u'photos/7/oc/pm/NwoCpmJLOphGJrl-full...
# description                      <p>On Feb 16, 2015 a federal judge ordered App...
# discoverable                                                                  True
# display_title                                  We Support Apple vs FBI NO BACKDOOR
# displayed_signature_count                                                        1
# displayed_supporter_count                                                        1
# end_date                                                       2016-04-14 00:00:00
# endorsements                                                                     0
# endorser_count                                                                   0
# fb_popularity                                                                    0
# id                                                                         6103410
# is_organization                                                              False
# is_pledge                                                                    False
# is_verified_victory                                                          False
# is_victory                                                                   False
# languages                                                                     [en]
# last_past_verified_victory_date                                                NaT
# last_past_victory_date                                                         NaT
# last_update                                                                    NaT
# letter_body                                    We support Apple vs FBI NO BACKDOOR
# links_fb_popularity                                                              0
# media                            {u'url': u'photos/5/eq/ic/tEEqiCDKdKlGtlg-full...
# milestones                                                                       0
# news_coverages                                                                   0
# num_comments                                                                     0
# num_past_petitions                                                               0
# num_past_verified_victories                                                      0
# num_past_victories                                                               0
# num_responses                                                                    0
# num_tweets                                                                       0
# original_locale                                                              en-US
# petition_status                                                             closed
# photo                            {u'url': u'photos/5/eq/ic/tEEqiCDKdKlGtlg-full...
# progress                                                                         1
# relevant_location                {u'city': None, u'photo_id': None, u'lat': Non...
# restricted_location                                                           None
# slug                                           we-support-apple-vs-fbi-no-backdoor
# status                                                                      closed
# tags                             [{u'photo_id': None, u'name': u'Apple vs FBI',...
# targets                          [{u'publicly_visible': True, u'slug': u'u-s-ho...
# topic                                                              criminaljustice
# tweets_followers                                                                 0
# twitter_popularity                                                               0
# user                             {u'website': None, u'city': None, u'first_name...
# video                                                                         None
# relevant_country                                                                US
#
#                                                                              10     \
# _id                                                       579d959051f2b8a00721ed65
# ask                              Lindy and Amanda's law: Create stricter laws t...
# calculated_goal                                                               2500
# comments_last_page                                                           False
# comments_likes                                                                   1
# created_at                                                     2015-08-29 16:29:51
# creator_name                                                           Ken Neikirk
# creator_photo                    {u'url': u'photos/0/db/yf/gaDBYftmeqlrgiw-full...
# description                      <p>Lindy and Amanda's Law</p>\n<p> </p>\n<p>It...
# discoverable                                                                  True
# display_title                    Cyndi Stevenson, Travis Hutson, Florida Govern...
# displayed_signature_count                                                     2419
# displayed_supporter_count                                                     2419
# end_date                                                       2015-09-12 00:00:00
# endorsements                                                                     0
# endorser_count                                                                   0
# fb_popularity                                                                    0
# id                                                                         4091588
# is_organization                                                              False
# is_pledge                                                                    False
# is_verified_victory                                                          False
# is_victory                                                                   False
# languages                                                                     [en]
# last_past_verified_victory_date                                                NaT
# last_past_victory_date                                                         NaT
# last_update                                                    2015-09-02 16:26:08
# letter_body                      Lindy and Amanda's law: Create stricter laws t...
# links_fb_popularity                                                              0
# media                            {u'url': u'photos/0/vj/co/moVJcoCSGoMiwYZ-full...
# milestones                                                                      12
# news_coverages                                                                   2
# num_comments                                                                   100
# num_past_petitions                                                               0
# num_past_verified_victories                                                      0
# num_past_victories                                                               0
# num_responses                                                                    0
# num_tweets                                                                       0
# original_locale                                                              en-US
# petition_status                                                             closed
# photo                            {u'url': u'photos/0/vj/co/moVJcoCSGoMiwYZ-full...
# progress                                                                     96.76
# relevant_location                {u'city': None, u'photo_id': None, u'lat': Non...
# restricted_location                                                           None
# slug                             cyndi-stevenson-travis-hutson-florida-governor...
# status                                                                      closed
# tags                             [{u'photo_id': 139992260, u'name': u'women', u...
# targets                          [{u'publicly_visible': False, u'slug': u'cyndi...
# topic                                                                         None
# tweets_followers                                                                 0
# twitter_popularity                                                               0
# user                             {u'website': None, u'city': u'Saint Augustine'...
# video                                                                         None
# relevant_country                                                                US
#
#                                                        ...                          \
# _id                                                    ...
# ask                                                    ...
# calculated_goal                                        ...
# comments_last_page                                     ...
# comments_likes                                         ...
# created_at                                             ...
# creator_name                                           ...
# creator_photo                                          ...
# description                                            ...
# discoverable                                           ...
# display_title                                          ...
# displayed_signature_count                              ...
# displayed_supporter_count                              ...
# end_date                                               ...
# endorsements                                           ...
# endorser_count                                         ...
# fb_popularity                                          ...
# ...
# milestones                                                                       7
# news_coverages                                                                   1
# num_comments                                                                    64
# num_past_petitions                                                               0
# num_past_verified_victories                                                      0
# num_past_victories                                                               0
# num_responses                                                                    0
# num_tweets                                                                       0
# original_locale                                                              en-US
# petition_status                                                             closed
# photo                            {u'url': u'photos/9/ia/af/sJiAafgqWAThdXH-full...
# progress                                                                        67
# relevant_location                {u'city': None, u'photo_id': None, u'lat': Non...
# restricted_location                                                           None
# slug                             richard-blumenthal-chris-murphy-jim-himes-rosa...
# status                                                                      closed
# tags                             [{u'photo_id': 141650807, u'name': u'politics'...
# targets                          [{u'publicly_visible': True, u'slug': u'richar...
# topic                                                                         None
# tweets_followers                                                                 0
# twitter_popularity                                                               0
# user                             {u'website': u'senatedems.ct.gov', u'city': u'...
# video                                                                         None
# relevant_country                                                                US
#
#                                                                              10082  \
# _id                                                       579e1d57a7c4008cc957c634
# ask                              Remove Martin Luther King Jr.'s name from all ...
# calculated_goal                                                                100
# comments_last_page                                                            True
# comments_likes                                                                   0
# created_at                                                     2015-07-14 14:29:48
# creator_name                                                     Franklin Dogooder
# creator_photo                                                                  NaN
# description                      This is important because Dr. King's message o...
# discoverable                                                                  True
# display_title                    U.S. Senate: Remove Martin Luther King Jr.'s n...
# displayed_signature_count                                                        2
# displayed_supporter_count                                                        2
# end_date                                                       2016-07-14 00:00:00
# endorsements                                                                     0
# endorser_count                                                                   0
# fb_popularity                                                                    0
# id                                                                         3747684
# is_organization                                                              False
# is_pledge                                                                    False
# is_verified_victory                                                          False
# is_victory                                                                   False
# languages                                                                     [en]
# last_past_verified_victory_date                                                NaT
# last_past_victory_date                                                         NaT
# last_update                                                                    NaT
# letter_body                      Remove Martin Luther King Jr.'s name from all ...
# links_fb_popularity                                                              0
# media                                                                          NaN
# milestones                                                                       0
# news_coverages                                                                   0
# num_comments                                                                     1
# num_past_petitions                                                               0
# num_past_verified_victories                                                      0
# num_past_victories                                                               0
# num_responses                                                                    0
# num_tweets                                                                       0
# original_locale                                                              en-US
# petition_status                                                             closed
# photo                                                                         None
# progress                                                                         2
# relevant_location                {u'city': None, u'photo_id': None, u'lat': Non...
# restricted_location                                                           None
# slug                             u-s-senate-remove-martin-luther-king-jr-s-name...
# status                                                                      closed
# tags                                                                            []
# targets                          [{u'publicly_visible': True, u'slug': u'u-s-se...
# topic                                                                         None
# tweets_followers                                                                 0
# twitter_popularity                                                               0
# user                             {u'website': u'', u'city': u'', u'first_name':...
# video                                                                         None
# relevant_country                                                                US
#
#                                                                              10083  \
# _id                                                       579e1d59a7c4008cc957c635
# ask                                                                        britany
# calculated_goal                                                                100
# comments_last_page                                                            True
# comments_likes                                                                   0
# created_at                                                     2015-07-15 19:04:27
# creator_name                                                           Brit Madden
# creator_photo                    {u'url': u'photos/6/dv/vh/oUDvVhmTSwKHwdX-full...
# description                         <p>be cuz they need to bring the show back</p>
# discoverable                                                                  True
# display_title                                          bring back 19 kids: britany
# displayed_signature_count                                                        1
# displayed_supporter_count                                                        1
# end_date                                                       2016-07-15 00:00:00
# endorsements                                                                     0
# endorser_count                                                                   0
# fb_popularity                                                                    0
# id                                                                         3753824
# is_organization                                                              False
# is_pledge                                                                    False
# is_verified_victory                                                          False
# is_victory                                                                   False
# languages                                                                     [en]
# last_past_verified_victory_date                                                NaT
# last_past_victory_date                                                         NaT
# last_update                                                                    NaT
# letter_body                                                                britany
# links_fb_popularity                                                              0
# media                                                                          NaN
# milestones                                                                       0
# news_coverages                                                                   0
# num_comments                                                                     0
# num_past_petitions                                                               0
# num_past_verified_victories                                                      0
# num_past_victories                                                               0
# num_responses                                                                    0
# num_tweets                                                                       0
# original_locale                                                              en-US
# petition_status                                                             closed
# photo                                                                         None
# progress                                                                         1
# relevant_location                {u'city': None, u'photo_id': None, u'lat': Non...
# restricted_location                                                           None
# slug                                                    bring-back-19-kids-britany
# status                                                                      closed
# tags                                                                            []
# targets                          [{u'publicly_visible': False, u'slug': u'kasha...
# topic                                                                         None
# tweets_followers                                                                 0
# twitter_popularity                                                               0
# user                             {u'website': None, u'city': u'womesldorf', u'f...
# video                                                                         None
# relevant_country                                                                US
#
#                                                                              10084
# _id                                                       579e1d38a7c4008cc957c62c
# ask                              We are asking you to block the parking of the ...
# calculated_goal                                                                500
# comments_last_page                                                            True
# comments_likes                                                                   6
# created_at                                                     2015-06-25 02:09:08
# creator_name                                                        Barbara Taylor
# creator_photo                    {u'url': u'photos/7/ms/yd/uZMSydlAqrMytzx-full...
# description                      <p>Charles (Charlie) Walker, an upstanding cit...
# discoverable                                                                  True
# display_title                    Mayor Joe Ford, Iaeger, WV, Earl Tomblin, Joe ...
# displayed_signature_count                                                      214
# displayed_supporter_count                                                      214
# end_date                                                       2016-06-25 00:00:00
# endorsements                                                                     0
# endorser_count                                                                   0
# fb_popularity                                                                    0
# id                                                                         3640024
# is_organization                                                              False
# is_pledge                                                                    False
# is_verified_victory                                                          False
# is_victory                                                                   False
# languages                                                                     [en]
# last_past_verified_victory_date                                                NaT
# last_past_victory_date                                                         NaT
# last_update                                                    2015-06-28 17:02:04
# letter_body                      We are asking you to block the parking of the ...
# links_fb_popularity                                                              0
# media                            {u'url': u'photos/4/qm/zo/MaqMZovoWFaeQwt-full...
# milestones                                                                       6
# news_coverages                                                                   0
# num_comments                                                                    76
# num_past_petitions                                                               0
# num_past_verified_victories                                                      0
# num_past_victories                                                               0
# num_responses                                                                    0
# num_tweets                                                                       0
# original_locale                                                              en-US
# petition_status                                                             closed
# photo                            {u'url': u'photos/4/qm/zo/MaqMZovoWFaeQwt-full...
# progress                                                                      42.8
# relevant_location                {u'city': None, u'photo_id': None, u'lat': Non...
# restricted_location                                                           None
# slug                             mayor-joe-ford-iaeger-wv-earl-tomblin-joe-manc...
# status                                                                      closed
# tags                                                                            []
# targets                          [{u'publicly_visible': False, u'slug': u'mayor...
# topic                                                                         None
# tweets_followers                                                                 0
# twitter_popularity                                                               0
# user                             {u'website': None, u'city': u'Papillion', u'fi...
# video                                                                         None
# relevant_country                                                                US
#
# [53 rows x 9992 columns]
